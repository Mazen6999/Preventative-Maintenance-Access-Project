# %% [markdown]
# # B1 & B3 elect.

# %% [markdown]
#
# <span style="color: cyan;">PM PLAN mills B1</span>

# %%
#PM plan mills B1
import pandas as pd

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    # range(start, stop, step)
    # We subtract 1 from start_week because Python lists are 0-indexed
    indices = range(start_week - 1, 52, period)
    
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Task Template: (Description, Code, Mins, Crew, Period_Freq)
# Note: Period_Freq here represents the interval (e.g., 26 = every 26 weeks)
tasks_template = [
    ("check motor connection",          130, 20, "1", 26),
    ("clean and check contactor",       160, 30, "1", 13),
    ("clean the panel",                 140, 30, "1", 13),
    ("check safties and mill brake",    170, 30, "1", 1),
    ("check limits and prox. Sw",       190, 30, "1", 4),
    ("check panel connection",          220, 30, "1", 13),
    ("check, clean slip ring brushes",  225, 45, "1", 13),
    ("check flow meter",                230, 15, "1", 13)
]

# Machine Definitions with their specific start offsets for Freq 13 and Freq 26
machines_config = [
    {
        "name": "B2.01.01", 
        "start_13": 13, 
        "start_26": 26
    },
    {
        "name": "B2.02.01", 
        "start_13": 12, 
        "start_26": 25
    },
    {
        "name": "B2.03.01", 
        "start_13": 11, 
        "start_26": 24
    }
]

data_rows = []

for mach in machines_config:
    for idx, task in enumerate(tasks_template, 1):
        desc, code, mins, crew, period = task
        
        # Determine the start week based on the period and machine rules
        if period == 13:
            start_week = mach["start_13"]
        elif period == 26:
            start_week = mach["start_26"]
        elif period == 4:
            start_week = 4  # Standard monthly start (can be changed if needed)
        else:
            start_week = 1  # Standard weekly start
            
        row = {
            'Machine': mach["name"],
            'Sub_Machine': '', 
            '.': idx,
            'Task_Description': desc,
            'Task_Code': code,
            'Estimated_mins': mins,
            'Crew': crew,
            'Period_freq': period
        }
        
        # Apply week flags
        week_flags = get_weeks(period, start_week)
        for w_idx, flag in enumerate(week_flags, 1):
            row[f'W{w_idx}'] = flag
            
        data_rows.append(row)

# Create DataFrame
df = pd.DataFrame(data_rows, columns=columns)

# Save to CSV
file_name = 'table/B2_Electrical_PM_Plan.csv'
df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File '{file_name}' generated successfully.")

# %% [markdown]
#
# <span style="color: cyan;">PM PLAN B1</span>

# %%
#PM PLAN B1
import pandas as pd
import os

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# B1 Task Template
tasks_template = [
    ("clean & check brushes & commutators", 100, 60, "1", 1),
    ("clean motors filter",                 110, 30, "1", 1),
    ("check motors connection",             130, 20, "1", 26),
    ("clean and check contactors",          160, 30, "1", 13),
    ("clean the panel",                     140, 30, "1", 13),
    ("check panel air condition",           150, 15, "1", 13),
    ("check safties",                       170, 30, "1", 1),
    ("check limits and prox. Sw (M)",       190, 30, "1", 4),
    ("check thermoregulation (M)",          195, 30, "1", 4),
    ("clean plc",                           210, 30, "1", 26),
    ("check coupling of tachometer",        215, 30, "1", 26),
    ("check panel connection",              220, 30, "1", 13),
    ("Check motor break",                   235, 90, "1", 13),
    ("Clean and check brushes of clutch",   240, 30, "1", 13)
]

machine_name = "B1"

data_rows = []

for idx, task in enumerate(tasks_template, 25):
    desc, code, mins, crew, period = task
    
    # Apply specific Start Week rules
    if period == 4:
        start_week = 1   
    elif period == 13:
        start_week = 13  
    elif period == 26:
        start_week = 23  
    else:
        start_week = 1   
        
    row = {
        'Machine': machine_name,
        'Sub_Machine': '', 
        '.': idx,
        'Task_Description': desc,
        'Task_Code': code,
        'Estimated_mins': mins,
        'Crew': crew,
        'Period_freq': period
    }
    
    week_flags = get_weeks(period, start_week)
    for w_idx, flag in enumerate(week_flags, 1):
        row[f'W{w_idx}'] = flag
        
    data_rows.append(row)

# Create DataFrame
df = pd.DataFrame(data_rows, columns=columns)

# Create the directory if it doesn't exist
output_folder = 'table'
os.makedirs(output_folder, exist_ok=True)

# Save to CSV in the specific folder
file_name = f'{output_folder}/B1_Electrical_PM_Plan.csv'
df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File saved to '{file_name}' successfully.")

# %% [markdown]
#
# <span style="color: cyan;">P.M PLAN 0 BELT,1&2&SATT</span>

# %%
#  P.M PLAN 0 BELT,1&2&SATT
import pandas as pd
import os

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    if start_week < 1: start_week = 1
    
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# --- Machine 1: 0-BELT.1 (Rows 2-11) ---
tasks_belt1 = [
    (2,  "clean motor filter",              110, 30, "1", 1),
    (3,  "check motor connection",          130, 20, "1", 26),
    (4,  "clean and check contactor",       160, 30, "1", 13),
    (5,  "clean the panel",                 140, 30, "1", 13),
    (6,  "check panel air condition",       150, 15, "1", 13),
    (7,  "check safeties",                  170, 30, "1", 1),
    (8,  "check limits and prox. Sw (M)",   190, 30, "1", 4),
    (9,  "check thermoregulation (M)",      195, 45, "1", 4),
    (10, "check panel connection",          220, 30, "1", 13),
    (11, "clean and fix photocell",         180, 10, "1", 4)
]

# --- Machine 2 & 3: 0-BELT.2 & SATT (Rows 1-9) ---
tasks_standard = [
    (1, "check motor connection",           130, 20, "1", 26),
    (2, "clean and check contactor",        160, 30, "1", 13),
    (3, "clean the panel",                  140, 30, "1", 13),
    (4, "check panel air condition",        150, 15, "1", 13),
    (5, "check safeties",                   170, 30, "1", 1),
    (6, "check limits and prox. Sw (M)",    190, 30, "1", 4),
    (7, "check thermoregulation (M)",       195, 45, "1", 4),
    (8, "check panel connection",           220, 30, "1", 13),
    (9, "clean and fix photocell",          180, 10, "1", 4)
]

data_rows = []

# --- Processing 0-BELT.1 ---
# Rules: Freq 26 -> W25. Freq 13 -> W13.
for item in tasks_belt1:
    idx, desc, code, mins, crew, period = item
    
    if period == 26: start_week = 25
    elif period == 13: start_week = 13
    elif period == 4: start_week = 1
    else: start_week = 1
    
    row = {
        'Machine': '0-BELT.1', 'Sub_Machine': '', '.': idx,
        'Task_Description': desc, 'Task_Code': code, 'Estimated_mins': mins,
        'Crew': crew, 'Period_freq': period
    }
    week_flags = get_weeks(period, start_week)
    for w_idx, flag in enumerate(week_flags, 1): row[f'W{w_idx}'] = flag
    data_rows.append(row)

# --- Processing 0-BELT.2 ---
# Rules: Freq 26 -> W26. Freq 13 -> W13.
for item in tasks_standard:
    idx, desc, code, mins, crew, period = item
    
    if period == 26: start_week = 26
    elif period == 13: start_week = 13
    elif period == 4: start_week = 1
    else: start_week = 1
    
    row = {
        'Machine': '0-BELT.2', 'Sub_Machine': '', '.': idx,
        'Task_Description': desc, 'Task_Code': code, 'Estimated_mins': mins,
        'Crew': crew, 'Period_freq': period
    }
    week_flags = get_weeks(period, start_week)
    for w_idx, flag in enumerate(week_flags, 1): row[f'W{w_idx}'] = flag
    data_rows.append(row)

# --- Processing SATT ---
# Rules: Freq 26 -> W26. Freq 13 -> W13.
for item in tasks_standard:
    idx, desc, code, mins, crew, period = item
    
    if period == 26: start_week = 26  # Corrected
    elif period == 13: start_week = 13 # Corrected
    elif period == 4: start_week = 1
    else: start_week = 1
    
    row = {
        'Machine': 'SATT', 'Sub_Machine': '', '.': idx,
        'Task_Description': desc, 'Task_Code': code, 'Estimated_mins': mins,
        'Crew': crew, 'Period_freq': period
    }
    week_flags = get_weeks(period, start_week)
    for w_idx, flag in enumerate(week_flags, 1): row[f'W{w_idx}'] = flag
    data_rows.append(row)

# Create DataFrame and Save
df = pd.DataFrame(data_rows, columns=columns)
output_folder = 'table'
os.makedirs(output_folder, exist_ok=True)
file_name = f'{output_folder}/0_BELT_SATT_Electrical_PM_Plan.csv'

df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File saved to '{file_name}' successfully.")

# %% [markdown]
#
# <span style="color: cyan;">PM.PLAN MILLS&C1&CNO  0.1&0.2</span>

# %%
import pandas as pd
import os

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    if start_week < 1: start_week = 1
    
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Task Template for C2.01, C2.02, C2.03 (derived from images)
# Format: (Description, Code, Mins, Crew, Period_Freq)
tasks_template = [
    ("check motor connection",          130, 20, "1", 26),
    ("clean and check contactor",       160, 30, "1", 13),
    ("clean the panel",                 140, 30, "1", 13),
    ("check safties and mill brake",    170, 30, "1", 1),
    ("check limits and prox. Sw",       190, 30, "1", 13), # Note: Freq 13 in C2 images
    ("check panel connection",          220, 30, "1", 13),
    ("check, clean slip ring brushes",  225, 45, "1", 13),
    ("check flow meter",                230, 15, "1", 13)
]

# Machine definitions with their starting row indices
machines_config = [
    {"name": "C2.01", "start_row": 16},
    {"name": "C2.02", "start_row": 24},
    {"name": "C2.03", "start_row": 32} # Image c08f00 starts at row 32 (implicit)
]

data_rows = []

for mach in machines_config:
    current_row_idx = mach["start_row"]
    
    for task in tasks_template:
        desc, code, mins, crew, period = task
        
        # Apply Start Week Rules
        if period == 26:
            start_week = 25
        elif period == 13:
            start_week = 13
        else:
            start_week = 1
            
        row = {
            'Machine': mach["name"],
            'Sub_Machine': '', 
            '.': current_row_idx,
            'Task_Description': desc,
            'Task_Code': code,
            'Estimated_mins': mins,
            'Crew': crew,
            'Period_freq': period
        }
        
        # Apply week flags
        week_flags = get_weeks(period, start_week)
        for w_idx, flag in enumerate(week_flags, 1):
            row[f'W{w_idx}'] = flag
            
        data_rows.append(row)
        current_row_idx += 1

# Create DataFrame and Save
df = pd.DataFrame(data_rows, columns=columns)
output_folder = 'table'
os.makedirs(output_folder, exist_ok=True)
file_name = f'{output_folder}/C2_Electrical_PM_Plan.csv'

df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File saved to '{file_name}' successfully.")
# Verification: Check start weeks for Freq 26 and 13
print(df[['Machine', 'Period_freq', 'W1', 'W13', 'W25']].head(8).to_string(index=False))

# %% [markdown]
# <span style="color: cyan;">  P.M  PLAN C1</span>

# %%
import pandas as pd
import os

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    if start_week < 1: start_week = 1
    
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Triplex Task Template (Extracted from image_c0a1e4.png)
# Format: (Description, Code, Mins, Crew, Period_Freq)
tasks_template = [
    ("clean & check brushes & commutator", 100, 60, "1", 1),
    ("clean motor filter",                 110, 30, "1", 1),
    ("check motor connection",             130, 20, "1", 26),
    ("clean and check contactor",          160, 30, "1", 13),
    ("clean the panel",                    140, 30, "1", 13),
    ("check panel air condition",          150, 15, "1", 13),
    ("check safties",                      170, 30, "1", 1),
    ("check limits and prox. Sw (M)",      190, 30, "1", 4),
    ("check thermoregulation (M)",         195, 120, "1", 4),
    ("clean plc",                          210, 30, "1", 26),
    ("check coupling of tachometer",       215, 30, "1", 26),
    ("check panel connection",             220, 30, "1", 13),
    ("check dancer operation (M)",         200, 30, "1", 4),
    ("check converter fan",                120, 45, "1", 13),
    ("Check tread width Camera",           423, 15, "1", 13),
    ("Check DR Noll sensors",              424, 15, "1", 13), # Corrected typo 'sesnsors'
    ("Check Profilometer sensors",         425, 15, "1", 13)  # Corrected typo 'sesnsors'
]

machine_name = "Triplex"
data_rows = []

for idx, task in enumerate(tasks_template, 1):
    desc, code, mins, crew, period = task
    
    # Apply Start Week Rules
    if period == 26:
        start_week = 25
    elif period == 13:
        start_week = 13
    else:
        start_week = 1 # Covers Freq 1 and Freq 4
        
    row = {
        'Machine': machine_name,
        'Sub_Machine': '', 
        '.': idx,
        'Task_Description': desc,
        'Task_Code': code,
        'Estimated_mins': mins,
        'Crew': crew,
        'Period_freq': period
    }
    
    # Apply week flags
    week_flags = get_weeks(period, start_week)
    for w_idx, flag in enumerate(week_flags, 1):
        row[f'W{w_idx}'] = flag
        
    data_rows.append(row)

# Create DataFrame and Save
df = pd.DataFrame(data_rows, columns=columns)
output_folder = 'table'
os.makedirs(output_folder, exist_ok=True)
file_name = f'{output_folder}/Triplex_Electrical_PM_Plan.csv'

df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File saved to '{file_name}' successfully.")
# Verification: Check start weeks for Freq 26, 13 and 4
print(df[df['Period_freq'].isin([4, 13, 26])][['Task_Description', 'Period_freq', 'W1', 'W13', 'W25']].head(10).to_string(index=False))

# %% [markdown]
#
# <span style="color: cyan;"> PLAN Mini ROLLER HEAD</span>

# %%
import pandas as pd
import os

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    if start_week < 1: start_week = 1
    
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Mini Roller Head Task Template (Extracted from image_c0fb80.png)
# Format: (Description, Code, Mins, Crew, Period_Freq)
tasks_template = [
    ("clean motor filter",              110, 30, "1", 1),
    ("check motor connection",          130, 20, "1", 26),
    ("clean and check contactor",       160, 30, "1", 13),
    ("clean the panel",                 140, 30, "1", 13),
    ("check panel air condition",       150, 15, "1", 13),
    ("check safties",                   170, 30, "1", 1),
    ("check limits and prox. Sw (M)",   190, 30, "1", 4),
    ("check thermoregulation (M)",      195, 90, "1", 4),
    ("clean plc",                       210, 30, "1", 26),
    ("check coupling of encoders",      215, 30, "1", 26),
    ("check panel connection",          220, 30, "1", 13),
    ("check dancer operation (M)",      200, 30, "1", 4),
    ("check converter fans",            120, 45, "1", 13),
    ("clean & fix photocell",           180, 10, "1", 13)
]

machine_name = "Mini ROLLER HEAD"
data_rows = []

for idx, task in enumerate(tasks_template, 1):
    desc, code, mins, crew, period = task
    
    # Apply Specific Start Week Rules
    if code == 130: # check motor connection
        start_week = 25
    elif code == 210: # clean plc
        start_week = 21
    elif code == 215: # check coupling of encoders
        start_week = 21
    elif period == 13:
        start_week = 13
    else:
        start_week = 1 # Covers Freq 1 and Freq 4 (and any other unassigned)
        
    row = {
        'Machine': machine_name,
        'Sub_Machine': '', 
        '.': idx,
        'Task_Description': desc,
        'Task_Code': code,
        'Estimated_mins': mins,
        'Crew': crew,
        'Period_freq': period
    }
    
    # Apply week flags
    week_flags = get_weeks(period, start_week)
    for w_idx, flag in enumerate(week_flags, 1):
        row[f'W{w_idx}'] = flag
        
    data_rows.append(row)

# Create DataFrame and Save
df = pd.DataFrame(data_rows, columns=columns)
output_folder = 'table'
os.makedirs(output_folder, exist_ok=True)
file_name = f'{output_folder}/Mini_Roller_Head_Electrical_PM_Plan.csv'

df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File saved to '{file_name}' successfully.")

# Verification: Check start weeks for the specific tasks mentioned
check_tasks = [130, 210, 215, 160] # Motor Conn, PLC, Encoders, Contactor (Freq 13)
print(df[df['Task_Code'].isin(check_tasks)][['Task_Description', 'Period_freq', 'W13', 'W21', 'W25']].to_string(index=False))
# Out:
# File saved to 'table/Mini_Roller_Head_Electrical_PM_Plan.csv' successfully.
#           Task_Description  Period_freq W13 W21 W25
#     check motor connection           26           x
#  clean and check contactor           13   x
#                  clean plc           26       x
# check coupling of encoders           26       x

# %% [markdown]
#
# <span style="color: cyan;">  PLAN ROLLER HEAD&DUPLEX&SINGEL</span>

# %%
import pandas as pd
import os

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    if start_week < 1: start_week = 1
    
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

data_rows = []

# ==========================================
# MACHINE 1: ROLLER HEAD
# Rules: Motor Conn @ W25. PLC/Coupling @ W21. Freq 13 @ W13.
# ==========================================
tasks_roller_head = [
    (1,  "clean motor filter",              110, 30, "1", 1),
    (2,  "check motor connection",          130, 20, "1", 26),
    (3,  "clean and check contactor",       160, 30, "1", 13),
    (4,  "clean the panel",                 140, 30, "1", 13),
    (5,  "check panel air condition",       150, 15, "1", 13),
    (6,  "check safties",                   170, 30, "1", 1),
    (7,  "check limits and prox. Sw (M)",   190, 30, "1", 4),
    (8,  "check thermoregulation (M)",      195, 90, "1", 4),
    (9,  "clean plc",                       210, 30, "1", 26),
    (10, "check coupling of encoders",      215, 30, "1", 26),
    (11, "check panel connection",          220, 30, "1", 13),
    (12, "check dancer operation (M)",      200, 30, "1", 4),
    (13, "check Inverter fans",             120, 45, "1", 13),
    (14, "clean & fix photocell",           180, 10, "1", 13)
]

for item in tasks_roller_head:
    idx, desc, code, mins, crew, period = item
    
    if code == 130:   start_week = 25  # Corrected to W25
    elif code == 210: start_week = 21  # W21
    elif code == 215: start_week = 21  # W21
    elif period == 13: start_week = 13
    else: start_week = 1
    
    row = {
        'Machine': 'ROLLER HEAD', 'Sub_Machine': '', '.': idx,
        'Task_Description': desc, 'Task_Code': code, 'Estimated_mins': mins,
        'Crew': crew, 'Period_freq': period
    }
    week_flags = get_weeks(period, start_week)
    for w_idx, flag in enumerate(week_flags, 1): row[f'W{w_idx}'] = flag
    data_rows.append(row)

# ==========================================
# MACHINE 2: DUPLEX & SINGLE
# Rules: Motor Conn @ W21. PLC/Coupling @ W21. Freq 13 @ W13.
# ==========================================
tasks_duplex = [
    (1,  "clean & check brushes & commutator", 100, 60, "1", 1),
    (2,  "clean motor filter",                 110, 30, "1", 1),
    (3,  "check motor connection",             130, 20, "1", 26),
    (4,  "clean and check contactor",          160, 30, "1", 13),
    (5,  "clean the panel",                    140, 30, "1", 13),
    (6,  "check panel air condition",          150, 15, "1", 13),
    (7,  "check safties",                      170, 30, "1", 1),
    (8,  "check limits and prox. Sw (M)",      190, 30, "1", 4),
    (9,  "check thermoregulation (M)",         195, 90, "1", 4),
    (10, "clean plc",                          210, 30, "1", 26),
    (11, "check coupling of tachometer and encoder", 215, 30, "1", 26),
    (12, "check panel connection",             220, 30, "1", 13),
    (13, "check dancer operation (M)",         200, 30, "1", 4),
    (14, "check Inverter fans",                120, 45, "1", 13),
    (15, "check flow meter",                   230, 15, "1", 13)
]

for item in tasks_duplex:
    idx, desc, code, mins, crew, period = item
    
    if code == 130:   start_week = 21  # Corrected to W21
    elif code == 210: start_week = 21  # W21
    elif code == 215: start_week = 21  # W21
    elif period == 13: start_week = 13
    else: start_week = 1
    
    row = {
        'Machine': 'DUPLEX & SINGLE', 'Sub_Machine': '', '.': idx,
        'Task_Description': desc, 'Task_Code': code, 'Estimated_mins': mins,
        'Crew': crew, 'Period_freq': period
    }
    week_flags = get_weeks(period, start_week)
    for w_idx, flag in enumerate(week_flags, 1): row[f'W{w_idx}'] = flag
    data_rows.append(row)

# Create DataFrame and Save
df = pd.DataFrame(data_rows, columns=columns)
output_folder = 'table'
os.makedirs(output_folder, exist_ok=True)
file_name = f'{output_folder}/Roller_Head_Duplex_Single_Electrical_PM_Plan.csv'

df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File saved to '{file_name}' successfully.")
# Verification: Print key tasks to confirm W25 vs W21 corrections
print("\nVerification (Machine | Task | Start Weeks):")
print(df[df['Task_Code'] == 130][['Machine', 'Task_Description', 'W21', 'W25', 'W26']].to_string(index=False))
# Out:
# File saved to 'table/Roller_Head_Duplex_Single_Electrical_PM_Plan.csv' successfully.
#
# Verification (Machine | Task | Start Weeks):
#         Machine       Task_Description W21 W25 W26
#     ROLLER HEAD check motor connection       x
# DUPLEX & SINGLE check motor connection   x

# %% [markdown]
#
# <span style="color: cyan;">  PM PLAN.C16</span>

# %%
import pandas as pd
import os

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    if start_week < 1: start_week = 1
    
    # range(start, stop, step)
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Task Template for C16 Machines
# Format: (Description, Code, Mins, Crew, Freq)
tasks_template = [
    ("check motor connection",          130, 20, "1", 24),
    ("clean the panel",                 140, 30, "1", 12),
    ("check safeties",                  170, 30, "1", 4),
    ("check limits and prox. Sw (M)",   190, 30, "1", 12),
    ("check panel connection",          220, 30, "1", 12),
    ("check motor break",               235, 30, "1", 12)
]

# Machine Configuration with explicit Start Weeks for each frequency group
machines_config = [
    {
        "name": "C16.1",
        "start_24": 21,
        "start_12": 9,
        "start_4": 1
    },
    {
        "name": "C16.2",
        "start_24": 22,
        "start_12": 10,
        "start_4": 2
    },
    {
        "name": "C16.3",
        "start_24": 23,
        "start_12": 11,
        "start_4": 3
    },
    {
        "name": "C16.4",
        "start_24": 24,
        "start_12": 12,
        "start_4": 4
    }
]

data_rows = []

for mach in machines_config:
    for idx, task in enumerate(tasks_template, 1):
        desc, code, mins, crew, freq = task
        
        # Determine Start Week based on Frequency and Machine Config
        if freq == 24:
            start_week = mach["start_24"]
        elif freq == 12:
            start_week = mach["start_12"]
        elif freq == 4:
            start_week = mach["start_4"]
        else:
            start_week = 1
            
        row = {
            'Machine': mach["name"],
            'Sub_Machine': '', 
            '.': idx,
            'Task_Description': desc,
            'Task_Code': code,
            'Estimated_mins': mins,
            'Crew': crew,
            'Period_freq': freq
        }
        
        # Apply week flags
        week_flags = get_weeks(freq, start_week)
        for w_idx, flag in enumerate(week_flags, 1):
            row[f'W{w_idx}'] = flag
            
        data_rows.append(row)

# Create DataFrame and Save
df = pd.DataFrame(data_rows, columns=columns)
output_folder = 'table'
os.makedirs(output_folder, exist_ok=True)
file_name = f'{output_folder}/C16_Electrical_PM_Plan.csv'

df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File saved to '{file_name}' successfully.")

# Verification: Print the staggered start weeks for "check motor connection" (Freq 24)
print("\nVerification (Machine | Task | Start Week):")
cols = ['Machine', 'Task_Description'] + [f'W{i}' for i in range(21, 26)]
print(df[df['Task_Code'] == 130][cols].to_string(index=False))
# Out:
# File saved to 'table/C16_Electrical_PM_Plan.csv' successfully.
#
# Verification (Machine | Task | Start Week):
# Machine       Task_Description W21 W22 W23 W24 W25
#   C16.1 check motor connection   x
#   C16.2 check motor connection       x
#   C16.3 check motor connection           x
#   C16.4 check motor connection               x

# %%
# PM PLAN.C15.1&2&3&4
import pandas as pd
import os

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    if start_week < 1: start_week = 1
    
    # range(start, stop, step)
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Task Template for C15 Machines
tasks_template = [
    ("check motor connection",          130, 20, "1", 24),
    ("clean the panel",                 140, 30, "1", 12),
    ("check safeties",                  170, 30, "1", 4),
    ("check limits and prox. Sw (M)",   190, 30, "1", 12),
    ("check panel connection",          220, 30, "1", 12),
    ("check motor break",               235, 30, "1", 12)
]

# Machine Configuration with explicit Start Weeks
machines_config = [
    {
        "name": "C15.1",
        "start_24": 21,
        "start_12": 9,
        "start_4": 1
    },
    {
        "name": "C15.2",
        "start_24": 22,
        "start_12": 10,
        "start_4": 2
    },
    {
        "name": "C15.3",
        "start_24": 23,
        "start_12": 11,
        "start_4": 3
    },
    {
        "name": "C15.4",
        "start_24": 24,
        "start_12": 12,
        "start_4": 4
    }
]

data_rows = []

for mach in machines_config:
    for idx, task in enumerate(tasks_template, 1):
        desc, code, mins, crew, freq = task
        
        # Determine Start Week based on Frequency and Machine Config
        if freq == 24:
            start_week = mach["start_24"]
        elif freq == 12:
            start_week = mach["start_12"]
        elif freq == 4:
            start_week = mach["start_4"]
        else:
            start_week = 1
            
        row = {
            'Machine': mach["name"],
            'Sub_Machine': '', 
            '.': idx,
            'Task_Description': desc,
            'Task_Code': code,
            'Estimated_mins': mins,
            'Crew': crew,
            'Period_freq': freq
        }
        
        # Apply week flags
        week_flags = get_weeks(freq, start_week)
        for w_idx, flag in enumerate(week_flags, 1):
            row[f'W{w_idx}'] = flag
            
        data_rows.append(row)

# Create DataFrame and Save
df = pd.DataFrame(data_rows, columns=columns)
output_folder = 'table'
os.makedirs(output_folder, exist_ok=True)
file_name = f'{output_folder}/C15_Electrical_PM_Plan.csv'

df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File saved to '{file_name}' successfully.")

# Verification: Print the staggered start weeks for "clean the panel" (Freq 12)
print("\nVerification (Machine | Task | Start Week):")
cols = ['Machine', 'Task_Description', 'W9', 'W10', 'W11', 'W12']
print(df[df['Task_Code'] == 140][cols].to_string(index=False))
# Out:
# File saved to 'table/C15_Electrical_PM_Plan.csv' successfully.
#
# Verification (Machine | Task | Start Week):
# Machine Task_Description W9 W10 W11 W12
#   C15.1  clean the panel  x
#   C15.2  clean the panel      x
#   C15.3  clean the panel          x
#   C15.4  clean the panel              x

# %%
# PM PLAN.C19
import pandas as pd
import os

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    if start_week < 1: start_week = 1
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Base Task Template
tasks_template = [
    ("check motor connection",          130, 20, "1", 24),
    ("clean the panel",                 140, 30, "1", 12),
    ("check safeties",                  170, 30, "1", 4),
    ("check limits and prox. Sw (M)",   190, 30, "1", 4),  # Default Freq 4 (overridden for C19.1)
    ("check panel connection",          220, 30, "1", 12),
    ("check motor break",               235, 30, "1", 12)
]

machines_config = [
    {"name": "C19.1", "start_24": 21, "start_12": 9,  "start_4": 1},
    {"name": "C19.2", "start_24": 22, "start_12": 10, "start_4": 2},
    {"name": "C19.3", "start_24": 23, "start_12": 11, "start_4": 3},
    {"name": "C19.4", "start_24": 24, "start_12": 12, "start_4": 4}
]

data_rows = []

for mach in machines_config:
    for idx, task in enumerate(tasks_template, 1):
        desc, code, mins, crew, freq = task
        
        # --- Handle Specific Exceptions ---
        
        # Exception for C19.1 Task 4 (Limits): It acts as Freq 12 starting at W9
        if mach["name"] == "C19.1" and code == 190:
            actual_freq = 12
            start_week = mach["start_12"]
            
        # Exception for C19.2/3/4 Task 4 (Limits): It is Freq 4 but ALWAYS starts W1 (does not stagger)
        elif mach["name"] != "C19.1" and code == 190:
            actual_freq = 4
            start_week = 1
            
        # Standard Logic
        else:
            actual_freq = freq
            if actual_freq == 24:
                start_week = mach["start_24"]
            elif actual_freq == 12:
                start_week = mach["start_12"]
            elif actual_freq == 4:
                start_week = mach["start_4"]
            else:
                start_week = 1
        
        row = {
            'Machine': mach["name"],
            'Sub_Machine': '', 
            '.': idx,
            'Task_Description': desc,
            'Task_Code': code,
            'Estimated_mins': mins,
            'Crew': crew,
            'Period_freq': actual_freq
        }
        
        week_flags = get_weeks(actual_freq, start_week)
        for w_idx, flag in enumerate(week_flags, 1):
            row[f'W{w_idx}'] = flag
            
        data_rows.append(row)

# Create DataFrame and Save
df = pd.DataFrame(data_rows, columns=columns)
output_folder = 'table'
os.makedirs(output_folder, exist_ok=True)
file_name = f'{output_folder}/C19_Electrical_PM_Plan.csv'

df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File saved to '{file_name}' successfully.")

# Verification: 
# 1. Check C19.1 Task 4 (Should be Freq 12, Start W9)
# 2. Check C19.2 Task 4 (Should be Freq 4, Start W1)
# 3. Check Staggered Safeties (Task 3)
print("\nVerification (Machine | Task | Freq | W1 | W2 | W9 | W10):")
verify_cols = ['Machine', 'Task_Description', 'Period_freq', 'W1', 'W2', 'W9', 'W10']
print(df[df['Task_Code'].isin([170, 190])][verify_cols].to_string(index=False))
# Out:
# File saved to 'table/C19_Electrical_PM_Plan.csv' successfully.
#
# Verification (Machine | Task | Freq | W1 | W2 | W9 | W10):
# Machine              Task_Description  Period_freq W1 W2 W9 W10
#   C19.1                check safeties            4  x     x
#   C19.1 check limits and prox. Sw (M)           12        x
#   C19.2                check safeties            4     x      x
#   C19.2 check limits and prox. Sw (M)            4  x     x
#   C19.3                check safeties            4
#   C19.3 check limits and prox. Sw (M)            4  x     x
#   C19.4                check safeties            4
#   C19.4 check limits and prox. Sw (M)            4  x     x

# %%
# PM PLAN.C19 (2)
import pandas as pd
import os

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    if start_week < 1: start_week = 1
    
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Base Task Template
tasks_template = [
    ("check motor connection",          130, 20, "1", 24),
    ("clean the panel",                 140, 30, "1", 12),
    ("check safeties",                  170, 30, "1", 4),
    ("check limits and prox. Sw (M)",   190, 30, "1", 4),
    ("check panel connection",          220, 30, "1", 12),
    ("check motor break",               235, 30, "1", 12)
]

# Corrected Machine Configuration based on your input
machines_config = [
    {"name": "C19.5", "start_24": 21, "start_12": 9,  "start_safe": 1},
    {"name": "C19.6", "start_24": 22, "start_12": 10, "start_safe": 2},
    {"name": "C19.7", "start_24": 23, "start_12": 11, "start_safe": 3},
    {"name": "C19.8", "start_24": 24, "start_12": 12, "start_safe": 4}
]

data_rows = []

for mach in machines_config:
    for idx, task in enumerate(tasks_template, 1):
        desc, code, mins, crew, freq = task
        
        # Determine Start Week
        if code == 190: # Task 4: Limits (Always starts W1)
            start_week = 1
            
        elif code == 170: # Task 3: Safeties (Staggered W1-W4)
            start_week = mach["start_safe"]
            
        elif freq == 24: # Task 1: Motor Conn (Staggered W21-W24)
            start_week = mach["start_24"]
            
        elif freq == 12: # Tasks 2, 5, 6 (Staggered W9-W12)
            start_week = mach["start_12"]
            
        else:
            start_week = 1
        
        row = {
            'Machine': mach["name"],
            'Sub_Machine': '', 
            '.': idx,
            'Task_Description': desc,
            'Task_Code': code,
            'Estimated_mins': mins,
            'Crew': crew,
            'Period_freq': freq
        }
        
        week_flags = get_weeks(freq, start_week)
        for w_idx, flag in enumerate(week_flags, 1):
            row[f'W{w_idx}'] = flag
            
        data_rows.append(row)

# Create DataFrame and Save
df = pd.DataFrame(data_rows, columns=columns)
output_folder = 'table'
os.makedirs(output_folder, exist_ok=True)
file_name = f'{output_folder}/C19_Part2_Electrical_PM_Plan.csv'

df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File saved to '{file_name}' successfully.")

# Verification Print
# 1. Check C19.5 Start Weeks (Should be W21, W9, W1)
# 2. Check C19.8 Start Weeks (Should be W24, W12, W4)
print("\nVerification (Machine | Task | Start Week):")
verify_cols = ['Machine', 'Task_Description', 'W1', 'W4', 'W9', 'W12', 'W21', 'W24']
# Filter for Motor Conn (130) and Safeties (170)
print(df[df['Task_Code'].isin([130, 170])][verify_cols].to_string(index=False))
# Out:
# File saved to 'table/C19_Part2_Electrical_PM_Plan.csv' successfully.
#
# Verification (Machine | Task | Start Week):
# Machine       Task_Description W1 W4 W9 W12 W21 W24
#   C19.5 check motor connection                x
#   C19.5         check safeties  x     x       x
#   C19.6 check motor connection
#   C19.6         check safeties
#   C19.7 check motor connection
#   C19.7         check safeties
#   C19.8 check motor connection                    x
#   C19.8         check safeties     x      x       x

# %%
# PM PLAN.C14 
import pandas as pd
import os

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    if start_week < 1: start_week = 1
    
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Task Template for C14 Machines
tasks_template = [
    ("clean & check brushes & commutator", 100, 60, "1", 2),
    ("clean motor filter",                 110, 30, "1", 2),
    ("check motor connection",             130, 20, "1", 26),
    ("clean and check contactor",          160, 30, "1", 12),
    ("clean the panel",                    140, 30, "1", 12),
    ("check panel air condition",          150, 15, "1", 12),
    ("check safeties",                     170, 30, "1", 2),
    ("check limits and prox. Sw (M)",      190, 30, "1", 4),
    ("check thermoregulation (M)",         195, 45, "1", 4),
    ("clean plc",                          210, 30, "1", 26),
    ("check coupling of tachometer",       215, 30, "1", 26),
    ("check panel connection",             220, 30, "1", 12),
    ("check motor break",                  235, 30, "1", 12)
]

# Machine Configuration
machines_config = [
    {"name": "C14.1", "start_2": 1, "start_12": 11},
    {"name": "C14.2", "start_2": 1, "start_12": 11},
    {"name": "C14.3", "start_2": 2, "start_12": 12},
    {"name": "C14.4", "start_2": 2, "start_12": 12}
]

data_rows = []

for mach in machines_config:
    for idx, task in enumerate(tasks_template, 1):
        desc, code, mins, crew, freq = task
        
        # Apply Logic
        if freq == 2:
            start_week = mach["start_2"]
        elif freq == 12:
            start_week = mach["start_12"]
        elif freq == 26:
            start_week = 26 # Fixed at W26
        elif freq == 4:
            start_week = 1  # Fixed at W1
        else:
            start_week = 1
        
        row = {
            'Machine': mach["name"],
            'Sub_Machine': '', 
            '.': idx,
            'Task_Description': desc,
            'Task_Code': code,
            'Estimated_mins': mins,
            'Crew': crew,
            'Period_freq': freq
        }
        
        week_flags = get_weeks(freq, start_week)
        for w_idx, flag in enumerate(week_flags, 1):
            row[f'W{w_idx}'] = flag
            
        data_rows.append(row)

# Create DataFrame and Save
df = pd.DataFrame(data_rows, columns=columns)
output_folder = 'table'
os.makedirs(output_folder, exist_ok=True)
file_name = f'{output_folder}/C14_Electrical_PM_Plan.csv'

df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File saved to '{file_name}' successfully.")

# Verification
# Check C14.1 (Start W1/W11) vs C14.3 (Start W2/W12)
print("\nVerification (Machine | Task | Freq | W1 | W2 | W11 | W12):")
verify_tasks = [100, 160] # Brushes (Freq 2), Contactors (Freq 12)
cols = ['Machine', 'Task_Description', 'Period_freq', 'W1', 'W2', 'W11', 'W12']
print(df[df['Task_Code'].isin(verify_tasks)][cols].to_string(index=False))
# Out:
# File saved to 'table/C14_Electrical_PM_Plan.csv' successfully.
#
# Verification (Machine | Task | Freq | W1 | W2 | W11 | W12):
# Machine                   Task_Description  Period_freq W1 W2 W11 W12
#   C14.1 clean & check brushes & commutator            2  x      x
#   C14.1          clean and check contactor           12         x
#   C14.2 clean & check brushes & commutator            2  x      x
#   C14.2          clean and check contactor           12         x
#   C14.3 clean & check brushes & commutator            2     x       x
#   C14.3          clean and check contactor           12             x
#   C14.4 clean & check brushes & commutator            2     x       x
#   C14.4          clean and check contactor           12             x

# %%
# P.M PLAN C12.G1.G1.1.C13 (2)بعد
import pandas as pd
import os

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    if start_week < 1: start_week = 1
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

data_rows = []

# ==========================================
# MACHINE: C12.1
# Logic: Freq 13 starts W13 (Corrected). Freq 26 starts W26. Freq 4 starts W1.
# ==========================================
tasks_c12_1 = [
    (1, "check motor connection", 130, 20, 1, 26),
    (2, "clean the panel", 140, 30, 1, 13),
    (3, "check panel air condition", 150, 15, 1, 13),
    (4, "check safties", 170, 30, 1, 1),
    (5, "check limits and prox. Sw (M)", 190, 30, 1, 4),
    (6, "check coupling of tachometer", 215, 30, 1, 26),
    (7, "check panel connection", 220, 30, 1, 13),
    (8, "check dancer operation (M)", 200, 30, 1, 4)
]

for item in tasks_c12_1:
    idx, desc, code, mins, crew, freq = item
    if freq == 26: start_week = 26
    elif freq == 13: start_week = 13  # Corrected to W13
    elif freq == 4: start_week = 1
    else: start_week = 1
    
    row = {'Machine': 'C12.1', 'Sub_Machine': '', '.': idx,
           'Task_Description': desc, 'Task_Code': code, 'Estimated_mins': mins,
           'Crew': crew, 'Period_freq': freq}
    
    week_flags = get_weeks(freq, start_week)
    for w_idx, flag in enumerate(week_flags, 1): row[f'W{w_idx}'] = flag
    data_rows.append(row)

# ==========================================
# MACHINE: C12.2
# Logic: Freq 13 starts W13. Freq 26 starts W26.
# ==========================================
tasks_c12_2 = [
    (10, "check motor connection", 130, 20, 1, 26),
    (11, "clean the panel", 140, 30, 1, 13),
    (12, "check panel air condition", 150, 15, 1, 13),
    (13, "check safties", 170, 30, 1, 1),
    (14, "check limits and prox. Sw (M)", 190, 30, 1, 4),
    (15, "check coupling of tachometer", 215, 30, 1, 26),
    (16, "check panel connection", 220, 30, 1, 13),
    (17, "check dancer operation (M)", 200, 30, 1, 4)
]

for item in tasks_c12_2:
    idx, desc, code, mins, crew, freq = item
    if freq == 26: start_week = 26
    elif freq == 13: start_week = 13
    elif freq == 4: start_week = 1
    else: start_week = 1
    
    row = {'Machine': 'C12.2', 'Sub_Machine': '', '.': idx,
           'Task_Description': desc, 'Task_Code': code, 'Estimated_mins': mins,
           'Crew': crew, 'Period_freq': freq}
    
    week_flags = get_weeks(freq, start_week)
    for w_idx, flag in enumerate(week_flags, 1): row[f'W{w_idx}'] = flag
    data_rows.append(row)

# ==========================================
# MACHINE: C13
# Logic: Freq 13 starts W13.
# ==========================================
tasks_c13 = [
    (18, "clean the panel", 140, 30, 1, 13),
    (19, "check safties", 170, 30, 1, 1),
    (20, "check limits and prox. Sw (M)", 190, 30, 1, 4),
    (21, "check panel connection", 220, 30, 1, 13)
]

for item in tasks_c13:
    idx, desc, code, mins, crew, freq = item
    if freq == 13: start_week = 13
    elif freq == 4: start_week = 1
    else: start_week = 1
    
    row = {'Machine': 'C13', 'Sub_Machine': '', '.': idx,
           'Task_Description': desc, 'Task_Code': code, 'Estimated_mins': mins,
           'Crew': crew, 'Period_freq': freq}
    
    week_flags = get_weeks(freq, start_week)
    for w_idx, flag in enumerate(week_flags, 1): row[f'W{w_idx}'] = flag
    data_rows.append(row)

# Create DataFrame and Save
df = pd.DataFrame(data_rows, columns=columns)
output_folder = 'table'
os.makedirs(output_folder, exist_ok=True)
file_name = f'{output_folder}/C12_C13_Electrical_PM_Plan.csv'

df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File saved to '{file_name}' successfully.")

# Verification
# C12.1 Panel (140) -> Should now be W13
print("\nVerification (Machine | Task | W13 | W14):")
print(df[df['Task_Code'] == 140][['Machine', 'Task_Description', 'W13', 'W14']].to_string(index=False))
