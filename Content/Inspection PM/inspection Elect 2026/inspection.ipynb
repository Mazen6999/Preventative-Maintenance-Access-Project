# %%
import pandas as pd
import os

# Create the directory if it doesn't exist
os.makedirs('table', exist_ok=True)

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    # range(start, stop, step)
    # We subtract 1 from start_week because Python lists are 0-indexed
    indices = range(start_week - 1, 52, period)
    
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Data extracted from the image
# Format: (Sub_Machine, Task_Description, Task_Code, Estimated_mins, Crew, Period_freq)
tasks_data = [
    # الكونتاكتور & الريلاي
    ("الكونتاكتور & الريلاي", "التأكد من الحركة الميكانيكية لريلاي التحكم و تنظيفه بسبراى و تغييره اذا لزم الأمر", 3.1, 60, "1E", 16),
    ("الكونتاكتور & الريلاي", "اعادة تربيط و تثبيت أطراف التوصيل", 3.2, 60, "1E", 16),

    # البانل الرئيسية
    ("البانل الرئيسية", "تنظيف البانل من الداخل باستخدام بلاور", 4.1, 30, "1E", 16),
    ("البانل الرئيسية", "التأكد من سلامة التوصيل لجميع مكونات القوى أو التحكم ( قاطع الدائرة – الريلاي – الروزيتة – الكونتاكتور )", 4.2, 60, "1E", 16),
    ("البانل الرئيسية", "التأكد من سلامة الكابلات من و الى البانل", 4.3, 20, "1E", 16),
    ("البانل الرئيسية", "التأكد من سلامة قاطع الدائرة", 4.4, 10, "1E", 16),

    # PLC بانل ال 
    ("PLC بانل ال ", "PLC توصيل و تثبيت المكونات الداخلية لل", 5.1, 10, "1E", 16),
    ("PLC بانل ال ", "تنظيف المكونات الداخلية لل PLC من الأتربة باستخدام سبراى مناسب", 5.2, 10, "1E", 16),

    # AC مواتير ال 
    ("AC مواتير ال ", "AC التاكد من سلامة مواتير ال", 13.1, 90, "1E", 16),
    ("AC مواتير ال ", "التأكد من سلامة الدرايف", 13.2, 20, "1E", 16),

    # السيليكتور سويتش
    ("السيليكتور سويتش", "التأكد من سلامة التوصيل الخاص بالسيليكتور سويتش و تغيير التالف منه", 12.1, 10, "1E", 16),
    ("السيليكتور سويتش", "اعادة تثبيت الأسلاك الغير مثبتة جيدا", 12.3, 20, "1E", 16),

    # الليميت سويتش و المحسات
    ("الليميت سويتش و المحسات", "ضبط الليمت سويتش و المحسات", 11.1, 60, "1E", 16),
    ("الليميت سويتش و المحسات", "ضبط سويتش الطوارىء", 11.2, 30, "1E", 16),
    ("الليميت سويتش و المحسات", "تنظيف و ضبط المحسات", 11.3, 60, "1E", 16),
]

machine_name = "Buffing MCH B1"
global_start_week = 4  # As requested

data_rows = []

for idx, task in enumerate(tasks_data, 1):
    sub_mach, desc, code, mins, crew, period = task
    
    row = {
        'Machine': machine_name,
        'Sub_Machine': sub_mach,
        '.': idx,
        'Task_Description': desc,
        'Task_Code': code,
        'Estimated_mins': mins,
        'Crew': crew,
        'Period_freq': period
    }
    
    # Apply week flags (Start Week 4 for everything)
    week_flags = get_weeks(period, global_start_week)
    for w_idx, flag in enumerate(week_flags, 1):
        row[f'W{w_idx}'] = flag
        
    data_rows.append(row)

# Create DataFrame
df = pd.DataFrame(data_rows, columns=columns)

# Save to CSV
file_name = 'table/B1_Electrical_PM_Plan.csv'
df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File '{file_name}' generated successfully.")
# Out:
# File 'table/B1_Electrical_PM_Plan.csv' generated successfully.

# %%
import pandas as pd
import os

# Create the directory if it doesn't exist
os.makedirs('table', exist_ok=True)

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Data extracted from the images (Conveyor System)
# Frequency is 16, Start Week is 4 (carried over from previous context)
tasks_data = [
    # الكونتاكتور & الريلاي
    ("الكونتاكتور & الريلاي", "التأكد من الحركة الميكانيكية لريلاي التحكم و تنظيفه بسبراى و تغييره اذا لزم الأمر", 3.1, 60, "1E", 16),
    ("الكونتاكتور & الريلاي", "اعادة تربيط و تثبيت أطراف التوصيل", 3.2, 60, "1E", 16),

    # البانل الرئيسية
    ("البانل الرئيسية", "تنظيف البانل من الداخل باستخدام بلاور", 4.1, 30, "1E", 16),
    ("البانل الرئيسية", "التأكد من سلامة التوصيل لجميع مكونات القوى أو التحكم ( قاطع الدائرة – الريلاي – الروزيتة – الكونتاكتور )", 4.2, 60, "1E", 16),
    ("البانل الرئيسية", "التأكد من سلامة الكابلات من و الى البانل", 4.3, 20, "1E", 16),
    ("البانل الرئيسية", "التأكد من سلامة قاطع الدائرة", 4.4, 10, "1E", 16),

    # PLC بانل ال 
    ("PLC بانل ال ", "PLC توصيل و تثبيت المكونات الداخلية لل", 5.1, 10, "1E", 16),
    ("PLC بانل ال ", " من الأتربة باستخدام سبراى مناسب PLC تنظيف المكونات الداخلية لل ", 5.2, 10, "1E", 16),

    # AC مواتير ال 
    ("AC مواتير ال ", "AC التأكد من سلامة مواتير ال ", 13.1, 90, "1E", 16),
    ("AC مواتير ال ", "التأكد من سلامة الدرايف", 13.2, 20, "1E", 16),

    # وحدة تكييف الهواء (From Image 2)
    ("وحدة تكييف الهواء", "التأكد من أن وحدة التكييف تعمل بحالة جيدة", 6.1, 10, "1E", 16),

    # السيليكتور سويتش
    ("السيليكتور سويتش", "التأكد من سلامة التوصيل الخاص بالسيليكتور سويتش و تغيير التالف منه", 12.1, 10, "1E", 16),
    ("السيليكتور سويتش", "اعادة تثبيت الأسلاك الغير مثبتة جيدا", 12.3, 20, "1E", 16),

    # الفوتوسيلات (From Image 2 - overrides "Limit Switches" from Image 1)
    ("الفوتوسيلات", "ضبط الفوتوسيلات و العواكس", 11.1, 60, "1E", 16),
    ("الفوتوسيلات", "ضبط سويتش الطوارىء", 11.2, 30, "1E", 16),
    ("الفوتوسيلات", "تنظيف و ضبط المحسات", 11.3, 60, "1E", 16),
]

machine_name = "Conveyor System"
global_start_week = 4 

data_rows = []

for idx, task in enumerate(tasks_data, 1):
    sub_mach, desc, code, mins, crew, period = task
    
    row = {
        'Machine': machine_name,
        'Sub_Machine': sub_mach,
        '.': idx,
        'Task_Description': desc,
        'Task_Code': code,
        'Estimated_mins': mins,
        'Crew': crew,
        'Period_freq': period
    }
    
    week_flags = get_weeks(period, global_start_week)
    for w_idx, flag in enumerate(week_flags, 1):
        row[f'W{w_idx}'] = flag
        
    data_rows.append(row)

# Create DataFrame
df = pd.DataFrame(data_rows, columns=columns)

# Save to CSV
file_name = 'table/Conveyor_System_PM_Plan.csv'
df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File '{file_name}' generated successfully.")
# Out:
# File 'table/Conveyor_System_PM_Plan.csv' generated successfully.

# %%
import pandas as pd
import os

# Create the directory if it doesn't exist
os.makedirs('table', exist_ok=True)

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Data extracted from the Mould Clean M/C image
# Freq: 12, Start: W11
tasks_data = [
    # الكونتاكتور & الريلاي
    ("الكونتاكتور & الريلاي", "التأكد من الحركة الميكانيكية لريلاي التحكم و تنظيفه بسبراى و تغييره اذا لزم الأمر", 3.1, 60, "1E", 12),
    ("الكونتاكتور & الريلاي", "اعادة تربيط و تثبيت أطراف التوصيل", 3.2, 60, "1E", 12),

    # البانل الرئيسية
    ("البانل الرئيسية", "تنظيف البانل من الداخل باستخدام بلاور", 4.1, 30, "1E", 12),
    ("البانل الرئيسية", "التأكد من سلامة التوصيل لجميع مكونات القوى أو التحكم ( قاطع الدائرة – الريلاي – الروزيتة – الكونتاكتور )", 4.2, 60, "1E", 12),
    ("البانل الرئيسية", "التأكد من سلامة الكابلات من و الى البانل", 4.3, 20, "1E", 12),
    ("البانل الرئيسية", "التأكد من سلامة قاطع الدائرة", 4.4, 10, "1E", 12),

    # السيليكتور سويتش
    ("السيليكتور سويتش", "التأكد من سلامة التوصيل الخاص بالسيليكتور سويتش و تغيير التالف منه", 12.1, 10, "1E", 12),
    ("السيليكتور سويتش", "اعادة تثبيت الأسلاك الغير مثبتة جيدا", 12.3, 20, "1E", 12),

    # الليمت سويتش & المحسات
    ("الليمت سويتش & المحسات", "ضبط الليمت سويتش و المحسات", 11.1, 60, "1E", 12),
    ("الليمت سويتش & المحسات", "ضبط سويتش الطوارىء", 11.2, 30, "1E", 12),
    ("الليمت سويتش & المحسات", "تنظيف و ضبط المحسات", 11.3, 60, "1E", 12),
]

machine_name = "Mould Clean M/C"
global_start_week = 11

data_rows = []

for idx, task in enumerate(tasks_data, 1):
    sub_mach, desc, code, mins, crew, period = task
    
    row = {
        'Machine': machine_name,
        'Sub_Machine': sub_mach,
        '.': idx,
        'Task_Description': desc,
        'Task_Code': code,
        'Estimated_mins': mins,
        'Crew': crew,
        'Period_freq': period
    }
    
    # Apply week flags
    week_flags = get_weeks(period, global_start_week)
    for w_idx, flag in enumerate(week_flags, 1):
        row[f'W{w_idx}'] = flag
        
    data_rows.append(row)

# Create DataFrame
df = pd.DataFrame(data_rows, columns=columns)

# Save to CSV
file_name = 'table/Mould_Clean_MC_Electrical_PM_Plan.csv'
df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File '{file_name}' generated successfully.")
# Out:
# File 'table/Mould_Clean_MC_Electrical_PM_Plan.csv' generated successfully.

# %%
import pandas as pd
import os

# Create the directory if it doesn't exist
os.makedirs('table', exist_ok=True)

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Tasks Data (Same for all machines)
# Freq is 12 for all
tasks_data = [
    # الكونتاكتور & الريلاي
    ("الكونتاكتور & الريلاي", "التأكد من الحركة الميكانيكية لريلاي التحكم و تنظيفه بسبراى و تغييره اذا لزم الأمر", 3.1, 60, "1E", 12),
    ("الكونتاكتور & الريلاي", "اعادة تربيط و تثبيت أطراف التوصيل", 3.2, 60, "1E", 12),

    # البانل الرئيسية
    ("البانل الرئيسية", "تنظيف البانل من الداخل باستخدام بلاور", 4.1, 30, "1E", 12),
    ("البانل الرئيسية", "التأكد من سلامة التوصيل لجميع مكونات القوى أو التحكم ( قاطع الدائرة – الريلاي – الروزيتة – الكونتاكتور )", 4.2, 60, "1E", 12),
    ("البانل الرئيسية", "التأكد من سلامة الكابلات من و الى البانل", 4.3, 20, "1E", 12),
    ("البانل الرئيسية", "التأكد من سلامة قاطع الدائرة", 4.4, 10, "1E", 12),

    # PLC بانل ال 
    ("PLC بانل ال ", "PLC توصيل و تثبيت المكونات الداخلية لل", 5.1, 10, "1E", 12),
    ("PLC بانل ال ", "تنظيف المكونات الداخلية لل PLC من الأتربة باستخدام سبراى مناسب", 5.2, 10, "1E", 12),

    # AC مواتير ال 
    ("AC مواتير ال ", "AC التاكد من سلامة مواتير ال", 13.1, 90, "1E", 12),
    ("AC مواتير ال ", "التأكد من سلامة الدرايف", 13.2, 20, "1E", 12),

    # السيليكتور سويتش
    ("السيليكتور سويتش", "التأكد من سلامة التوصيل الخاص بالسيليكتور سويتش و تغيير التالف منه", 12.1, 10, "1E", 12),
    ("السيليكتور سويتش", "اعادة تثبيت الأسلاك الغير مثبتة جيدا", 12.3, 20, "1E", 12),

    # الليمت سويتش & المحسات
    ("الليمت سويتش & المحسات", "ضبط الليمت سويتش و المحسات", 11.1, 60, "1E", 12),
    ("الليمت سويتش & المحسات", "ضبط سويتش الطوارىء", 11.2, 30, "1E", 12),
    ("الليمت سويتش & المحسات", "تنظيف و ضبط المحسات", 11.3, 60, "1E", 12),
]

# Machine Configuration (Staggered Starts)
machines_config = [
    {"name": "P1", "start_week": 6},
    {"name": "P2", "start_week": 7},
    {"name": "P3", "start_week": 8}
]

data_rows = []

for mach in machines_config:
    for idx, task in enumerate(tasks_data, 1):
        sub_mach, desc, code, mins, crew, period = task
        
        row = {
            'Machine': mach['name'],
            'Sub_Machine': sub_mach,
            '.': idx,
            'Task_Description': desc,
            'Task_Code': code,
            'Estimated_mins': mins,
            'Crew': crew,
            'Period_freq': period
        }
        
        # Apply week flags based on specific machine start week
        week_flags = get_weeks(period, mach['start_week'])
        for w_idx, flag in enumerate(week_flags, 1):
            row[f'W{w_idx}'] = flag
            
        data_rows.append(row)

# Create DataFrame
df = pd.DataFrame(data_rows, columns=columns)

# Save to CSV
file_name = 'table/Painting_Machines_PM_Plan.csv'
df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File '{file_name}' generated successfully.")
# Out:
# File 'table/Painting_Machines_PM_Plan.csv' generated successfully.

# %%
import pandas as pd
import os

# Create the directory if it doesn't exist
os.makedirs('table', exist_ok=True)

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Data extracted from Plunger Test Machine image
# Freq: 16, Start: W4
tasks_data = [
    # الكونتاكتور & الريلاي
    ("الكونتاكتور & الريلاي", "التأكد من الحركة الميكانيكية لريلاي التحكم و تنظيفه بسبراى و تغييره اذا لزم الأمر", 3.1, 60, "1E", 16),
    ("الكونتاكتور & الريلاي", "اعادة تربيط و تثبيت أطراف التوصيل", 3.2, 60, "1E", 16),

    # البانل الرئيسية
    ("البانل الرئيسية", "تنظيف البانل من الداخل باستخدام بلاور", 4.1, 30, "1E", 16),
    ("البانل الرئيسية", "التأكد من سلامة التوصيل لجميع مكونات القوى أو التحكم ( قاطع الدائرة – الريلاي – الروزيتة – الكونتاكتور )", 4.2, 60, "1E", 16),
    ("البانل الرئيسية", "التأكد من سلامة الكابلات من و الى البانل", 4.3, 20, "1E", 16),
    ("البانل الرئيسية", "التأكد من سلامة قاطع الدائرة", 4.4, 10, "1E", 16),

    # AC مواتير ال 
    ("AC مواتير ال ", "AC التاكد من سلامة مواتير ال", 13.1, 90, "1E", 16),
    ("AC مواتير ال ", "التأكد من سلامة الدرايف", 13.2, 20, "1E", 16),

    # السيليكتور سويتش
    ("السيليكتور سويتش", "التأكد من سلامة التوصيل الخاص بالسيليكتور سويتش و تغيير التالف منه", 12.1, 10, "1E", 16),
    ("السيليكتور سويتش", "اعادة تثبيت الأسلاك الغير مثبتة جيدا", 12.3, 20, "1E", 16),

    # الليمت سويتش و المحسات
    ("الليمت سويتش و المحسات", "ضبط الليمت سويتش و المحسات", 11.1, 60, "1E", 16),
    ("الليمت سويتش و المحسات", "ضبط سويتش الطوارىء", 11.2, 30, "1E", 16),
    ("الليمت سويتش و المحسات", "تنظيف و ضبط المحسات", 11.3, 60, "1E", 16),
]

machine_name = "Plunger Test Machine"
global_start_week = 4

data_rows = []

for idx, task in enumerate(tasks_data, 1):
    sub_mach, desc, code, mins, crew, period = task
    
    row = {
        'Machine': machine_name,
        'Sub_Machine': sub_mach,
        '.': idx,
        'Task_Description': desc,
        'Task_Code': code,
        'Estimated_mins': mins,
        'Crew': crew,
        'Period_freq': period
    }
    
    # Apply week flags
    week_flags = get_weeks(period, global_start_week)
    for w_idx, flag in enumerate(week_flags, 1):
        row[f'W{w_idx}'] = flag
        
    data_rows.append(row)

# Create DataFrame
df = pd.DataFrame(data_rows, columns=columns)

# Save to CSV
file_name = 'table/Plunger_Test_Machine_PM_Plan.csv'
df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File '{file_name}' generated successfully.")
# Out:
# File 'table/Plunger_Test_Machine_PM_Plan.csv' generated successfully.

# %%
import pandas as pd
import os

# Create the directory if it doesn't exist
os.makedirs('table', exist_ok=True)

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    # range(start, stop, step)
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Data Definition
# Format: (Task_Description, Task_Code, Estimated_mins, Crew, Period_freq)
tasks_data = [
    ("Cleaning Visual Signaling Devices", 8.1, 60, "1E", 1),
    ("Checking Emergency", 8.2, 60, "1E", 1),
    ("Manual Movements Check", 8.3, 30, "1M", 1),
    ("Checking Electric Boards Filters", 8.4, 60, "1E", 1),
    ("Checking Safety Doors", 8.5, 20, "1E", 1),
    ("General Clean", 8.6, 30, "1M", 1),
    ("Cleaning Air Filters", 8.7, 90, "1M", 1),
    ("Checking pneumatic leakage", 8.8, 20, "1M", 1),
    ("Checking sensors fixation", 8.9, 10, "1M", 4),
    ("Checking mechanical stops original positions", 9.0, 20, "1M", 4),
    ("Replacing Electric Boards Filters", 9.1, 60, "1E", 52),
    ("Replacing compressed air Filters", 9.2, 30, "1M", 52),
    ("Calibrating transducers", 9.3, 60, "1E", 52),
    ("Checking pneumatic valves", 9.4, 60, "1M", 52),
    ("Checking hub bearing", 9.5, 60, "1M", 4),
    ("Checking grease level of drum", 9.6, 60, "1M", 52),
    ("Checking seal conditions", 9.7, 30, "1M", 52),
    ("Checking roller belt wear condition", 9.8, 60, "1M", 26),
    ("Cleaning filter of the motor", 9.9, 60, "1E", 26),
    ("Checking drives", 10.0, 60, "1E", 52),
]

machine_name = "Rolling Resistance Machine"
sub_machine_name = "Rolling Resistance"

data_rows = []

for idx, task in enumerate(tasks_data, 1):
    desc, code, mins, crew, period = task
    
    # --- Custom Scheduling Logic ---
    if code == 9.9:
        # Special case: Cleaning filter of the motor starts Week 28
        start_week = 28
    elif period == 1:
        # Freq 1 starts Week 1
        start_week = 1
    else:
        # All others start Week 2
        start_week = 2
    # -------------------------------

    row = {
        'Machine': machine_name,
        'Sub_Machine': sub_machine_name,
        '.': idx,
        'Task_Description': desc,
        'Task_Code': code,
        'Estimated_mins': mins,
        'Crew': crew,
        'Period_freq': period
    }
    
    # Generate the 'x' flags
    week_flags = get_weeks(period, start_week)
    for w_idx, flag in enumerate(week_flags, 1):
        row[f'W{w_idx}'] = flag
        
    data_rows.append(row)

# Create DataFrame
df = pd.DataFrame(data_rows, columns=columns)

# Save to CSV
file_name = 'table/Rolling_Resistance_PM_Plan.csv'
df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File '{file_name}' generated successfully.")
# Out:
# File 'table/Rolling_Resistance_PM_Plan.csv' generated successfully.

# %%
import pandas as pd
import os

# Create the directory if it doesn't exist
os.makedirs('table', exist_ok=True)

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Data extracted from Scherography 2 image
# Freq: 15, Start: W11
tasks_data = [
    # Contactor and relay
    ("Contactor and relay", "Checking mechanical movement of control relay and cleaning", 3.1, 60, "1E", 15),
    ("Contactor and relay", "Rewiring and connecting wires", 3.2, 60, "1E", 15),

    # Main Panel
    ("Main Panel", "Cleanning the Panel using blower", 4.1, 30, "1E", 15),
    ("Main Panel", "checking all panel componenets (power & Control) for example ( C.B, Contactors, ..)", 4.2, 60, "1E", 15),
    ("Main Panel", "Checking cables conditon from and to the panel and camera cables aslo", 4.3, 20, "1E", 15),
    ("Main Panel", "Testing C.B correct operation and condition", 4.4, 10, "1E", 15),

    # PLC Panel
    ("PLC Panel", "Reconnection and checking all PLC modules", 5.1, 10, "1E", 15),
    ("PLC Panel", "Cleanning all PLC modules and components", 5.2, 10, "1E", 15),

    # Air condition Unit
    ("Air condition Unit", "Checking Air cond. Unit operation and Temp.", 6.1, 10, "1E", 15),

    # Selector SW
    ("Selector SW", "Checking the wiring of selector Sw and replace defected", 12.1, 10, "1E", 15),
    ("Selector SW", "rewiring all weak wires of selector SW", 12.3, 20, "1E", 15),

    # Motors and Drives
    ("Motors and Drives", "checking and testing motors and drives in all directions", 13.1, 60, "1E", 15),
    ("Motors and Drives", "Testing all proximities and sensors of movment Axis", 11.2, 30, "1E", 15),
    ("Motors and Drives", "setting tires measurment sensors", 11.3, 60, "1E", 15),
]

machine_name = "Scherography 2"
global_start_week = 11

data_rows = []

for idx, task in enumerate(tasks_data, 1):
    sub_mach, desc, code, mins, crew, period = task
    
    row = {
        'Machine': machine_name,
        'Sub_Machine': sub_mach,
        '.': idx,
        'Task_Description': desc,
        'Task_Code': code,
        'Estimated_mins': mins,
        'Crew': crew,
        'Period_freq': period
    }
    
    # Apply week flags
    week_flags = get_weeks(period, global_start_week)
    for w_idx, flag in enumerate(week_flags, 1):
        row[f'W{w_idx}'] = flag
        
    data_rows.append(row)

# Create DataFrame
df = pd.DataFrame(data_rows, columns=columns)

# Save to CSV
file_name = 'table/Scherography_2_Electrical_PM_Plan.csv'
df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File '{file_name}' generated successfully.")
# Out:
# File 'table/Scherography_2_Electrical_PM_Plan.csv' generated successfully.

# %%
import pandas as pd
import os

# Create the directory if it doesn't exist
os.makedirs('table', exist_ok=True)

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Data extracted from Scherography image
# Freq: 15, Start: W10
tasks_data = [
    # Contactor and relay
    ("Contactor and relay", "Checking mechanical movement of control relay and cleaning", 3.1, 60, "1E", 15),
    ("Contactor and relay", "Rewiring and connecting wires", 3.2, 60, "1E", 15),

    # Main Panel
    ("Main Panel", "Cleanning the Panel using blower", 4.1, 30, "1E", 15),
    ("Main Panel", "checking all panel componenets (power & Control) for example ( C.B, Contactors, ..)", 4.2, 60, "1E", 15),
    ("Main Panel", "Checking cables conditon from and to the panel and camera cables aslo", 4.3, 20, "1E", 15),
    ("Main Panel", "Testing C.B correct operation and condition", 4.4, 10, "1E", 15),

    # PLC Panel
    ("PLC Panel", "Reconnection and checking all PLC modules", 5.1, 10, "1E", 15),
    ("PLC Panel", "Cleanning all PLC modules and components", 5.2, 10, "1E", 15),

    # Air condition Unit
    ("Air condition Unit", "Checking Air cond. Unit operation and Temp.", 6.1, 10, "1E", 15),

    # Selector SW
    ("Selector SW", "Checking the wiring of selector Sw and replace defected", 12, 10, "1E", 15),
    ("Selector SW", "rewiring all weak wires of selector SW", 12, 20, "1E", 15),

    # Motors and Drives
    ("Motors and Drives", "checking and testing motors and drives in all directions", 13, 60, "1E", 15),
    ("Motors and Drives", "Testing all proximities and sensors of movment Axis", 11.2, 30, "1E", 15),
    ("Motors and Drives", "setting tires measurment sensors", 11.3, 60, "1E", 15),
]

machine_name = "Scherography"
global_start_week = 10

data_rows = []

for idx, task in enumerate(tasks_data, 1):
    sub_mach, desc, code, mins, crew, period = task
    
    row = {
        'Machine': machine_name,
        'Sub_Machine': sub_mach,
        '.': idx,
        'Task_Description': desc,
        'Task_Code': code,
        'Estimated_mins': mins,
        'Crew': crew,
        'Period_freq': period
    }
    
    # Apply week flags
    week_flags = get_weeks(period, global_start_week)
    for w_idx, flag in enumerate(week_flags, 1):
        row[f'W{w_idx}'] = flag
        
    data_rows.append(row)

# Create DataFrame
df = pd.DataFrame(data_rows, columns=columns)

# Save to CSV
file_name = 'table/Scherography_Electrical_PM_Plan.csv'
df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File '{file_name}' generated successfully.")
# Out:
# File 'table/Scherography_Electrical_PM_Plan.csv' generated successfully.

# %%
import pandas as pd
import os

# Create the directory if it doesn't exist
os.makedirs('table', exist_ok=True)

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    # range(start, stop, step)
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Data extracted from Test tire M/C 3 image
# User Instruction: All tasks Freq 13, Start W5
tasks_data = [
    # الكونتاكتور & الريلاي
    ("الكونتاكتور & الريلاي", "التأكد من الحركة الميكانيكية لريلاي التحكم و تنظيفه بسبراى و تغييره اذا لزم الأمر", 3.1, 60, "1E", 13),
    ("الكونتاكتور & الريلاي", "اعادة تربيط و تثبيت أطراف التوصيل", 3.2, 60, "1E", 13),

    # البانل الرئيسية
    ("البانل الرئيسية", "تنظيف البانل من الداخل باستخدام بلاور", 4.1, 30, "1E", 13),
    ("البانل الرئيسية", "التأكد من سلامة التوصيل لجميع مكونات القوى أو التحكم ( قاطع الدائرة – الريلاي – الروزيتة – الكونتاكتور )", 4.2, 60, "1E", 13),
    ("البانل الرئيسية", "التأكد من سلامة الكابلات من و الى البانل", 4.3, 20, "1E", 13),
    ("البانل الرئيسية", "التأكد من سلامة قاطع الدائرة", 4.4, 10, "1E", 13),

    # بانل ال PLC
    ("PLC بانل ال", "PLC توصيل و تثبيت المكونات الداخلية لل", 5.1, 10, "1E", 13),
    ("PLC بانل ال", "تنظيف المكونات الداخلية لل PLC من الأتربة باستخدام سبراى مناسب", 5.2, 10, "1E", 13), # Forced to 13

    # وحدة تكييف الهواء
    ("وحدة تكييف الهواء", "التأكد من أن وحدة التكييف تعمل بحالة جيدة", 6.1, 10, "1E", 13), # Forced to 13

    # السيليكتور سويتش
    ("السيليكتور سويتش", "التأكد من سلامة التوصيل الخاص بالسيليكتور سويتش و تغيير التالف منه", 12.1, 10, "1E", 13), # Forced to 13
    ("السيليكتور سويتش", "اعادة تثبيت الأسلاك الغير مثبتة جيدا", 12.3, 20, "1E", 13), # Forced to 13

    # الروود وييل Road wheel
    ("الروود وييل Road wheel", "التأكد من سلامة الموتور و من سلامة فرش الشربون", 16, 60, "1E", 13),

    # محسات السفتى
    ("محسات السفتى", "التأكد من سلامة جميع محسات السفتى Safety Sensors", 17, 60, "1E", 13),

    # الليمت سويتش & المحسات
    ("الليمت سويتش & المحسات", "ضبط الليمت سويتش و المحسات", 11.1, 60, "1E", 13),
    ("الليمت سويتش & المحسات", "ضبط سويتش الطوارىء", 11.2, 30, "1E", 13),
    ("الليمت سويتش & المحسات", "تنظيف و ضبط المحسات", 11.3, 60, "1E", 13),
]

machine_name = "Test tire M/C 3"
global_start_week = 5

data_rows = []

for idx, task in enumerate(tasks_data, 1):
    sub_mach, desc, code, mins, crew, period = task
    
    row = {
        'Machine': machine_name,
        'Sub_Machine': sub_mach,
        '.': idx,
        'Task_Description': desc,
        'Task_Code': code,
        'Estimated_mins': mins,
        'Crew': crew,
        'Period_freq': period
    }
    
    # Apply week flags (Start Week 5 for everything)
    week_flags = get_weeks(period, global_start_week)
    for w_idx, flag in enumerate(week_flags, 1):
        row[f'W{w_idx}'] = flag
        
    data_rows.append(row)

# Create DataFrame
df = pd.DataFrame(data_rows, columns=columns)

# Save to CSV
file_name = 'table/Test_Tire_MC_3_Electrical_PM_Plan.csv'
df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File '{file_name}' generated successfully.")
# Out:
# File 'table/Test_Tire_MC_3_Electrical_PM_Plan.csv' generated successfully.

# %%
import pandas as pd
import os

# Create the directory if it doesn't exist
os.makedirs('table', exist_ok=True)

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    # range(start, stop, step)
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Data extracted from Test tire M/C 3 image
# User Instruction: All tasks Freq 13, Start W5
tasks_data = [
    # الكونتاكتور & الريلاي
    ("الكونتاكتور & الريلاي", "التأكد من الحركة الميكانيكية لريلاي التحكم و تنظيفه بسبراى و تغييره اذا لزم الأمر", 3.1, 60, "1E", 13),
    ("الكونتاكتور & الريلاي", "اعادة تربيط و تثبيت أطراف التوصيل", 3.2, 60, "1E", 13),

    # البانل الرئيسية
    ("البانل الرئيسية", "تنظيف البانل من الداخل باستخدام بلاور", 4.1, 30, "1E", 13),
    ("البانل الرئيسية", "التأكد من سلامة التوصيل لجميع مكونات القوى أو التحكم ( قاطع الدائرة – الريلاي – الروزيتة – الكونتاكتور )", 4.2, 60, "1E", 13),
    ("البانل الرئيسية", "التأكد من سلامة الكابلات من و الى البانل", 4.3, 20, "1E", 13),
    ("البانل الرئيسية", "التأكد من سلامة قاطع الدائرة", 4.4, 10, "1E", 13),

    # بانل ال PLC
    ("PLC بانل ال", "PLC توصيل و تثبيت المكونات الداخلية لل", 5.1, 10, "1E", 13),
    ("PLC بانل ال", "تنظيف المكونات الداخلية لل PLC من الأتربة باستخدام سبراى مناسب", 5.2, 10, "1E", 13), # Forced to 13

    # وحدة تكييف الهواء
    ("وحدة تكييف الهواء", "التأكد من أن وحدة التكييف تعمل بحالة جيدة", 6.1, 10, "1E", 13), # Forced to 13

    # السيليكتور سويتش
    ("السيليكتور سويتش", "التأكد من سلامة التوصيل الخاص بالسيليكتور سويتش و تغيير التالف منه", 12.1, 10, "1E", 13), # Forced to 13
    ("السيليكتور سويتش", "اعادة تثبيت الأسلاك الغير مثبتة جيدا", 12.3, 20, "1E", 13), # Forced to 13

    # الروود وييل Road wheel
    ("الروود وييل Road wheel", "التأكد من سلامة الموتور و من سلامة فرش الشربون", 16, 60, "1E", 13),

    # محسات السفتى
    ("محسات السفتى", "التأكد من سلامة جميع محسات السفتى Safety Sensors", 17, 60, "1E", 13),

    # الليمت سويتش & المحسات
    ("الليمت سويتش & المحسات", "ضبط الليمت سويتش و المحسات", 11.1, 60, "1E", 13),
    ("الليمت سويتش & المحسات", "ضبط سويتش الطوارىء", 11.2, 30, "1E", 13),
    ("الليمت سويتش & المحسات", "تنظيف و ضبط المحسات", 11.3, 60, "1E", 13),
]

machine_name = "Test tire M/C 4"
global_start_week = 5

data_rows = []

for idx, task in enumerate(tasks_data, 1):
    sub_mach, desc, code, mins, crew, period = task
    
    row = {
        'Machine': machine_name,
        'Sub_Machine': sub_mach,
        '.': idx,
        'Task_Description': desc,
        'Task_Code': code,
        'Estimated_mins': mins,
        'Crew': crew,
        'Period_freq': period
    }
    
    # Apply week flags (Start Week 5 for everything)
    week_flags = get_weeks(period, global_start_week)
    for w_idx, flag in enumerate(week_flags, 1):
        row[f'W{w_idx}'] = flag
        
    data_rows.append(row)

# Create DataFrame
df = pd.DataFrame(data_rows, columns=columns)

# Save to CSV
file_name = 'table/Test_Tire_MC_4_Electrical_PM_Plan.csv'
df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File '{file_name}' generated successfully.")
# Out:
# File 'table/Test_Tire_MC_4_Electrical_PM_Plan.csv' generated successfully.

# %%
import pandas as pd
import os

# Create the directory if it doesn't exist
os.makedirs('table', exist_ok=True)

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    # range(start, stop, step)
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Tasks Data extracted from the image
# Freq is 12 for all
tasks_data = [
    # الكونتاكتور & الريلاي
    ("الكونتاكتور & الريلاي", "التأكد من الحركة الميكانيكية لريلاي التحكم و تنظيفه بسبراى و تغييره اذا لزم الأمر", 3.1, 60, "1E", 12),
    ("الكونتاكتور & الريلاي", "اعادة تربيط و تثبيت أطراف التوصيل", 3.2, 60, "1E", 12),

    # البانل الرئيسية
    ("البانل الرئيسية", "تنظيف البانل من الداخل باستخدام بلاور", 4.1, 30, "1E", 12),
    ("البانل الرئيسية", "التأكد من سلامة التوصيل لجميع مكونات القوى أو التحكم ( قاطع الدائرة – الريلاي – الروزيتة – الكونتاكتور )", 4.2, 60, "1E", 12),
    ("البانل الرئيسية", "التأكد من سلامة الكابلات من و الى البانل", 4.3, 20, "1E", 12),
    ("البانل الرئيسية", "التأكد من سلامة قاطع الدائرة", 4.4, 10, "1E", 12),

    # بانل ال PLC
    ("PLC بانل ال", "PLC توصيل و تثبيت المكونات الداخلية لل", 5.1, 10, "1E", 12),
    ("PLC بانل ال", "تنظيف المكونات الداخلية لل PLC من الأتربة باستخدام سبراى مناسب", 5.2, 10, "1E", 12),

    # مواتير ال AC
    ("AC مواتير ال", "AC التاكد من سلامة مواتير ال", 13.1, 90, "1E", 12),
    ("AC مواتير ال", "التأكد من سلامة الدرايف", 13.2, 20, "1E", 12),

    # السيليكتور سويتش
    ("السيليكتور سويتش", "التأكد من سلامة التوصيل الخاص بالسيليكتور سويتش و تغيير التالف منه", 12.1, 10, "1E", 12),
    ("السيليكتور سويتش", "اعادة تثبيت الأسلاك الغير مثبتة جيدا", 12.3, 20, "1E", 12),

    # الليمت سويتش & المحسات
    ("الليمت سويتش & المحسات", "ضبط الليمت سويتش و المحسات", 11.1, 60, "1E", 12),
    ("الليمت سويتش & المحسات", "ضبط سويتش الطوارىء", 11.2, 30, "1E", 12),
    ("الليمت سويتش & المحسات", "تنظيف و ضبط المحسات", 11.3, 60, "1E", 12),
]

# Machine Configuration (Staggered Starts)
machines_config = [
    {"name": "T1 Trimming machine", "start_week": 6},
    {"name": "T2 Trimming machine", "start_week": 7}
]

data_rows = []

for mach in machines_config:
    for idx, task in enumerate(tasks_data, 1):
        sub_mach, desc, code, mins, crew, period = task
        
        row = {
            'Machine': mach['name'],
            'Sub_Machine': sub_mach,
            '.': idx,
            'Task_Description': desc,
            'Task_Code': code,
            'Estimated_mins': mins,
            'Crew': crew,
            'Period_freq': period
        }
        
        # Apply week flags based on specific machine start week
        week_flags = get_weeks(period, mach['start_week'])
        for w_idx, flag in enumerate(week_flags, 1):
            row[f'W{w_idx}'] = flag
            
        data_rows.append(row)

# Create DataFrame
df = pd.DataFrame(data_rows, columns=columns)

# Save to CSV
file_name = 'table/Trimming_Machines_PM_Plan.csv'
df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File '{file_name}' generated successfully.")
# Out:
# File 'table/Trimming_Machines_PM_Plan.csv' generated successfully.

# %%
import pandas as pd
import os

# Create the directory if it doesn't exist
os.makedirs('table', exist_ok=True)

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Data extracted from Uniformity machine image
# Freq: 12, Start: W5
tasks_data = [
    ("Checking the Mech. Movement of the relay and replacement if needed.", 3.1, 60, "1E", 12),
    ("Checking and reconnecting wires", 3.2, 60, "1E", 12),
    ("Cleaning the Panel with blower", 4.1, 30, "1E", 12),
    ("Checking all Panel components ( control and Power ) [ C.B, Contactors, ..]", 4.2, 60, "1E", 12),
    ("Checking cables condition from and to the panel", 4.3, 20, "1E", 12),
    ("Connecting and fixing PLC modules", 4.4, 10, "1E", 12),
    ("Cleaning PLC modules using spray", 5.1, 10, "1E", 12),
    ("Checking working of Air condition", 5.2, 10, "1E", 12),
    ("Testing all selectors Movements", 6.1, 10, "1E", 12),
    ("Rewiring the selector and replacement for defected", 12.1, 10, "1E", 12),
    ("Testing the probes positions", 12.3, 20, "1E", 12),
    ("Measuring Chuck width", 14, 90, "1E", 12),
    ("Testing motor and brushes", 15, 90, "1E", 12),
    ("Testing all safety sensors", 16, 60, "1E", 12),
    ("Fixing LS arms", 17, 60, "1E", 12),
    ("setting for safety relays", 11.1, 60, "1E", 12),
    ("setting and cleaning sensors", 11.2, 30, "1E", 12),
]

machine_name = "Uniformity"
global_start_week = 5

data_rows = []

for idx, task in enumerate(tasks_data, 1):
    desc, code, mins, crew, period = task
    
    row = {
        'Machine': machine_name,
        'Sub_Machine': machine_name, # Empty as per image structure
        '.': idx,
        'Task_Description': desc,
        'Task_Code': code,
        'Estimated_mins': mins,
        'Crew': crew,
        'Period_freq': period
    }
    
    # Apply week flags
    week_flags = get_weeks(period, global_start_week)
    for w_idx, flag in enumerate(week_flags, 1):
        row[f'W{w_idx}'] = flag
        
    data_rows.append(row)

# Create DataFrame
df = pd.DataFrame(data_rows, columns=columns)

# Save to CSV
file_name = 'table/Uniformity_Electrical_PM_Plan.csv'
df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File '{file_name}' generated successfully.")
# Out:
# File 'table/Uniformity_Electrical_PM_Plan.csv' generated successfully.

# %%
import pandas as pd
import os

# Create the directory if it doesn't exist
os.makedirs('table', exist_ok=True)

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    # range(start, stop, step)
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Data extracted from Unbalance machine image
# Format: (Task_Description, Task_Code, Estimated_mins, Crew, Period_freq, Start_Week)
tasks_data = [
    ("Check the function of relays,fuses&power contacors.", "Un18", 90, "1", 52, 7),
    ("Check the grease of cardan drive shafts.", "Un19", 30, "1", 52, 7),
    ("Check &grease bearing of motor", "Un20", 60, "1", 16, 7),
    ("Check pressure container sealing.", "Un21", 90, "1", 8, 6),
    ("clean cooling air paths.", "Un22", 60, "1", 8, 6),
    ("check the shaft sealing ring", "Un23", 60, "1", 8, 6),
    ("Check &replace motor ball bearing", "Un24", 45, "1", 16, 7),
]

machine_name = "Unbalance Machine"

data_rows = []

for idx, task in enumerate(tasks_data, 1):
    desc, code, mins, crew, period, start_week = task
    
    row = {
        'Machine': machine_name,
        'Sub_Machine': '', 
        '.': idx,
        'Task_Description': desc,
        'Task_Code': code,
        'Estimated_mins': mins,
        'Crew': crew,
        'Period_freq': period
    }
    
    # Apply week flags based on the specific start week for this task
    week_flags = get_weeks(period, start_week)
    for w_idx, flag in enumerate(week_flags, 1):
        row[f'W{w_idx}'] = flag
        
    data_rows.append(row)

# Create DataFrame
df = pd.DataFrame(data_rows, columns=columns)

# Save to CSV
file_name = 'table/Unbalance_Machine_PM_Plan.csv'
df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File '{file_name}' generated successfully.")
# Out:
# File 'table/Unbalance_Machine_PM_Plan.csv' generated successfully.

# %%
import pandas as pd
import os

# Create the directory if it doesn't exist
os.makedirs('table', exist_ok=True)

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    # range(start, stop, step)
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Tasks Data extracted from the image
# All tasks have Freq 10
tasks_data = [
    # الكونتاكتور & الريلاي
    ("الكونتاكتور & الريلاي", "التأكد من الحركة الميكانيكية لريلاي التحكم و تنظيفه بسبراى و تغييره اذا لزم الأمر", 3.1, 60, "1E", 10),
    ("الكونتاكتور & الريلاي", "اعادة تربيط و تثبيت أطراف التوصيل", 3.2, 60, "1E", 10),

    # البانل الرئيسية
    ("البانل الرئيسية", "تنظيف البانل من الداخل باستخدام بلاور", 4.1, 30, "1E", 10),
    ("البانل الرئيسية", "التأكد من سلامة التوصيل لجميع مكونات القوى أو التحكم ( قاطع الدائرة – الريلاي – الروزيتة – الكونتاكتور )", 4.2, 60, "1E", 10),
    ("البانل الرئيسية", "التأكد من سلامة الكابلات من و الى البانل", 4.3, 20, "1E", 10),
    ("البانل الرئيسية", "التأكد من سلامة قاطع الدائرة", 4.4, 10, "1E", 10),

    # بانل ال PLC
    ("PLC بانل ال", "PLC توصيل و تثبيت المكونات الداخلية لل", 5.1, 10, "1E", 10),
    ("PLC بانل ال", "تنظيف المكونات الداخلية لل PLC من الأتربة باستخدام سبراى مناسب", 5.2, 10, "1E", 10),

    # مواتير ال AC
    ("AC مواتير ال", "التأكد من سلامة مواتير ال AC", 13.1, 90, "1E", 10),
    ("AC مواتير ال", "التأكد من سلامة الدرايف", 13.2, 20, "1E", 10),

    # السيليكتور سويتش
    ("السيليكتور سويتش", "التأكد من سلامة التوصيل الخاص بالسيليكتور سويتش و تغيير التالف منه", 12.1, 10, "1E", 10),
    ("السيليكتور سويتش", "اعادة تثبيت الأسلاك الغير مثبتة جيدا", 12.3, 20, "1E", 10),

    # الليمت سويتش & المحسات
    ("الليمت سويتش & المحسات", "ضبط الليمت سويتش و المحسات", 11.1, 60, "1E", 10),
    ("الليمت سويتش & المحسات", "ضبط سويتش الطوارىء", 11.2, 30, "1E", 10),
    ("الليمت سويتش & المحسات", "تنظيف و ضبط المحسات", 11.3, 60, "1E", 10),
]

# Machine Configuration (Staggered Starts V1-V7)
machines_config = [
    {"name": "Visual Machine V1", "start_week": 4},
    {"name": "Visual Machine V2", "start_week": 5},
    {"name": "Visual Machine V3", "start_week": 6},
    {"name": "Visual Machine V4", "start_week": 7},
    {"name": "Visual Machine V5", "start_week": 8},
    {"name": "Visual Machine V6", "start_week": 9},
    {"name": "Visual Machine V7", "start_week": 10},
]

data_rows = []

for mach in machines_config:
    for idx, task in enumerate(tasks_data, 1):
        sub_mach, desc, code, mins, crew, period = task
        
        row = {
            'Machine': mach['name'],
            'Sub_Machine': sub_mach,
            '.': idx,
            'Task_Description': desc,
            'Task_Code': code,
            'Estimated_mins': mins,
            'Crew': crew,
            'Period_freq': period
        }
        
        # Apply week flags based on specific machine start week
        week_flags = get_weeks(period, mach['start_week'])
        for w_idx, flag in enumerate(week_flags, 1):
            row[f'W{w_idx}'] = flag
            
        data_rows.append(row)

# Create DataFrame
df = pd.DataFrame(data_rows, columns=columns)

# Save to CSV
file_name = 'table/Visual_Machines_PM_Plan.csv'
df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File '{file_name}' generated successfully.")
# Out:
# File 'table/Visual_Machines_PM_Plan.csv' generated successfully.

# %%
import pandas as pd
import os

# Create the directory if it doesn't exist
os.makedirs('table', exist_ok=True)

# Define the columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper function to generate week flags
def get_weeks(period, start_week):
    weeks = [''] * 52
    # range(start, stop, step)
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Tasks Data extracted from the image
# Freq changed to 12 (was 13 in image)
tasks_data = [
    ("Checking mechanical movement of control relay and cleaning", "X15", 60, "1E", 12),
    ("Checking MP1 of both stations and the operation panel", "X16", 60, "1E", 12),
    ("Cleanning the Panel using blower and Rewiring and connecting wires", "X17", 30, "1E", 12),
    ("checking all panel componenets (power & Control) for example ( C.B, Contactors, ..)", "X18", 60, "1E", 12),
    ("Checking cables conditon from and to the panel and Banner tire measurment system", "X19", 20, "1E", 12),
    ("Checking the Tube and testing all movements and directions", "X20", 10, "1E", 12),
    ("Reconnection and checking all PLC modules", "X21", 10, "1E", 12),
    ("Cleanning all PLC modules and components", "X22", 10, "1E", 12),
    ("Checking Air cond. Unit operation and Temp.", "X23", 10, "1E", 12),
    ("Testing Main C.B correct operation and condition", "X24", 10, "1E", 12),
    ("Checking diode and claibrate images ( white and Black for both stations )", "X25", 20, "1E", 12),
    ("checking and testing motors and drives in all directions", "X26", 60, "1E", 12),
    ("Testing all proximities and sensors of movment Axis  for ( feeding , testing and outlet conveyors )", "X27", 30, "1E", 12),
    ("setting tires measurment sensors", "X28", 60, "1E", 12),
]

# Machine Configuration (Staggered Starts)
machines_config = [
    {"name": "X-Ray COLLMAN", "start_week": 1},
    {"name": "X-Ray ALFA", "start_week": 2},
    {"name": "X-Ray MONSANTO", "start_week": 3}
]

data_rows = []

for mach in machines_config:
    for idx, task in enumerate(tasks_data, 1):
        desc, code, mins, crew, period = task
        
        row = {
            'Machine': mach['name'],
            'Sub_Machine': '',
            '.': idx,
            'Task_Description': desc,
            'Task_Code': code,
            'Estimated_mins': mins,
            'Crew': crew,
            'Period_freq': period
        }
        
        # Apply week flags based on specific machine start week
        week_flags = get_weeks(period, mach['start_week'])
        for w_idx, flag in enumerate(week_flags, 1):
            row[f'W{w_idx}'] = flag
            
        data_rows.append(row)

# Create DataFrame
df = pd.DataFrame(data_rows, columns=columns)

# Save to CSV
file_name = 'table/XRay_Machines_PM_Plan.csv'
df.to_csv(file_name, index=False, encoding='utf-8-sig')

print(f"File '{file_name}' generated successfully.")
# Out:
# File 'table/XRay_Machines_PM_Plan.csv' generated successfully.

# %%
import pandas as pd
import os

# Create the directory
os.makedirs('table', exist_ok=True)

# Define columns
columns = [
    'Machine', 'Sub_Machine', '.', 'Task_Description', 'Task_Code',
    'Estimated_mins', 'Crew', 'Period_freq',
] + [f'W{i}' for i in range(1, 53)]

# Helper to generate weeks
def get_weeks(period, start_week):
    weeks = [''] * 52
    indices = range(start_week - 1, 52, period)
    for i in indices:
        weeks[i] = 'x'
    return weeks

# Helper to parse frequency string to (Period, Start_Week)
def parse_freq(f_str):
    f_str = f_str.strip().lower()
    if f_str == 'w':
        return 1, 1      # Starts Week 1
    elif f_str == 'm':
        return 4, 4      # Starts Week 4
    elif f_str == '3m':
        return 13, 12    # Starts Week 12
    elif f_str == '6m':
        return 26, 26    # Starts Week 26
    elif f_str == 'y':
        return 52, 52    # Starts Week 52
    else:
        return 4, 4      # Default

# Raw Data extracted from all 5 images
# Format: (Sub_Machine, Index, Description, Mins, Crew, Freq_String)
all_tasks = [
    # Image 1
    ("PNEUMATICS", 1, "Maintenance device, filter and pressure accumulator: Clean filter, replace if necessary", 60, "1E", "y"),
    ("PNEUMATICS", 2, "Hose lines and airconnections: Check leak tightness of connections;Check hoses for damage and wear (cracks)", 60, "1E", "6m"),
    ("CENTRAL LUBRICATION", 3, "Fluid grease unit : Refill with Shell Gadus S4 V45AC (Alternative: Shell Alvania 1029)", 30, "1M", "3m"),
    ("CENTRAL LUBRICATION", 4, "Pressure switch: Check function with PLC-ServiceMode", 60, "1E", "w"),
    ("CENTRAL LUBRICATION", 5, "Function check: Check lubrication function withPLC-ServiceMode.", 20, "1E", "w"),
    ("CENTRAL LUBRICATION", 6, "Hose lines and connections: Check leak tightness of connections;Check hoses for damage and wear (cracks)", 30, "1M", "3m"),
    ("LUBRICATION HYDRAULICS", 7, "Pressure settings: Check settings acc. to hydraulic plan", 90, "1M", "y"),
    ("LUBRICATION HYDRAULICS", 8, "Filterelement : Check and replace if necessary", 20, "1M", "y"),
    ("LUBRICATION HYDRAULICS", 9, "Hose line and connectings: Check leak tightness of connections;Check hoses for damage and wear (cracks)", 10, "1M", "6m"),
    ("LUBRICATION HYDRAULICS", 10, "Oil Level: Check oil level and quality of oil;Fill with Shell Tellus S2 MX 22 (Alternative: Mobil Velocite No. 10 ISO VG 22)", 20, "1M", "m"),
    ("ELECTRIC COMPONENTS", 11, "Ventilator measuring computer : Change filter", 60, "1E", "m"),
    ("ELECTRIC COMPONENTS", 12, "Uninterruptible power supply UPS: Check the power supply of the battery acc. to manufacturer specifications", 30, "1M", "6m"),
    ("ELECTRIC COMPONENTS", 13, "Cooling system swith cabinet: Check cooling function; Change filter", 60, "1E", "m"),
    ("ELECTRIC COMPONENTS", 14, "Wiring: Visual inspection of the wiring especially in energy chains and drive connections", 60, "1M", "6m"),
    ("ELECTRIC COMPONENTS", 15, "Every Emergency stop buttons: Checkfor damage and function", 60, "1M", "6m"),

    # Image 2
    ("ROBOT UNIT", 1, "Every unit: Check all units for damage / exceeding wear and loose / missing parts", 60, "1E", "m"),
    ("ROBOT UNIT", 2, "Hose Package: Check for wear and smooth movement", 60, "1E", "m"),
    ("In-conveyor roboter-marking unit", 3, "Toothed belt: Clean and replace if necessary", 30, "1M", "6m"),
    ("In-conveyor roboter-marking unit", 4, "Toothed belt disc: Clean and replace if necessary", 60, "1E", "6m"),
    ("COUNTERHOLD", 5, "Guide carriages and rails: Clean, check for damage and replace if necessary", 20, "1E", "m"),
    ("COUNTERHOLD", 6, "toothed bar drive: Clean, check for damage and replace if necessary toothed bar, toothed wheel, lubrication wheel", 30, "1M", "m"),
    ("CHANGE ROTATION UNIT", 7, ":Check all units for damage / exceeding wear and loose / missing parts", 90, "1M", "m"),
    ("MANUAL RIM CHANGE MRC", 8, "crane: Check all units for damage / exceeding wear and loose / missing parts", 20, "1M", "m"),
    ("RIM CHANGING TOOL", 9, "tool upper rim: Check all units for damage / exceeding wear and loose / missing parts", 10, "1M", "m"),
    ("RIM CHANGING TOOL", 10, "rim lower rim: Check all units for damage/ exceeding wear and loose/ missing parts", 20, "1M", "m"),

    # Image 3
    ("DRIVE", 1, "Guide carriages and rails: cean , check for damage and replace if necessary", 60, "1E", "m"),
    ("DRIVE", 2, "friction lining: check for wear and replace if necessary", 60, "1E", "m"),
    ("Horizontal carriage Geometry measuring unit", 3, "Ball screw: Clean, check for damage and replace if necessary", 30, "1M", "m"),
    ("Horizontal carriage Geometry measuring unit", 4, "Guide carriages and rails: Clean, check for damage and replace if necessary", 60, "1E", "m"),
    ("Vertical carriage Geometry measuring unit", 5, "Ball screw: Clean, check for damage and replace if necessary", 20, "1E", "m"),
    ("Vertical carriage Geometry measuring unit", 6, "Guide carriages and rails: Clean, check for damage and replace if necessary", 30, "1M", "m"),
    ("GEOMETRY MEASURING DEVICE", 7, "Camera unit (Pos. 10): Clean sensor window with glass cleaner or similar; Check sensor, cable connections, and sensor coverage for damage", 90, "1M", "m"),
    ("Carriage drum unit", 8, "Ball screw: Clean, check for damage and replace if necessary", 20, "1M", "m"),
    ("Carriage drum unit", 9, "Guide carriages and rails: Clean, check for damage and replace if necessary", 10, "1M", "3m"),
    ("DRUM COMPL.", 10, "Load wheel surface (Pos. 200): Clean coated surfaces with dry ice and a brass wire brush or a hard bristle brush to remove rubber residues", 20, "1M", "6m"),
    ("DRUM COMPL.", 11, "Load wheel surface (Pos. 200): Check axial run-out of the drum", 60, "1E", "3m"),
    ("DRUM COMPL.", 12, "Grease nipple: Grease with Isoflex NBU 15", 30, "1M", "3m"),
    ("DRUM COMPL.", 13, "Force sensor: Clean, check for visible damage and replace if necessary", 60, "1E", "m"),
    ("TROMMELANTRIEB", 14, "Guide carriages and rails: Clean, check for damage and replace if necessary", 60, "1M", "m"),
    ("TROMMELANTRIEB", 15, "friction lining: check for wear and replace if necessary", 60, "1M", "m"),
    ("PUSHER", 16, ":Check all units for damage / exceeding wear and loose / missing parts", 60, "1M", "3m"),
    ("PUSHER", 17, "Guide carriages and rails: Clean, check for damage and replace if necessary", 30, "1M", "m"),
    ("INTEGR. MEASURE DEV.", 18, "Function: Clean the lens", 60, "1M", "m"),
    ("TEMP MEASURE DEV.", 19, "Function: Clean the lens", 60, "1E", "m"),

    # Image 4
    ("SOAP SOLUTION SUPPLY", 1, "Collecting pan,filter,pump:Clean inner surfaces of the soap tank & check wear's hoses", 60, "1E", "m"),
    ("MEASURING STATION LUB6TBR", 2, "Every unit: Check all units for damage/exceeding wear and loose/missing parts", 60, "1E", "m"),
    ("IN-CONVEYOR", 3, "toothed belt: Clean and replace if necessary", 30, "1M", "6m"),
    ("IN-CONVEYOR", 4, "Toothed belt disc: Clean and replace if necessary", 60, "1E", "6m"),
    ("CARRIAGE", 5, "Guide carriages and rails: Clean,check for damage and replace if necessary", 20, "1E", "m"),
    ("LIFTING DEVICE", 6, ": Check for damage and leakage and replace if necessary", 30, "1M", "m"),
    ("LIFTING DEVICE", 7, "Guide carriages and rails: Clean,check for damage and replace if necessary", 90, "1M", "m"),
    ("LIFTING DEVICE", 8, "Toothed bar drive: Clean,check for damage and replace if necessary toothed bar,toothed wheel,lubrication wheel", 20, "1M", "m"),
    ("LIFTING UNIT", 9, ": Clean,check for damage and replace if necessary", 10, "1M", "m"),
    ("LIFTING UNIT", 10, "Guide carriages and rails: Clean,check for damage and replace if necessary", 20, "1M", "m"),
    ("LIFTING UNIT", 11, "Toothed bar drive: Clean,check for damage and replace if necessary toothed bar,toothed wheel,lubrication wheel", 60, "1E", "m"),
    ("INTERLOCKING", 12, "function: Check radial & axial run-out relating to spindle,contact surfaces to rim & spindle, check damper", 30, "1M", "m"),
    ("BEARING", 13, "Spindle thread: Clean the threadwith a bish and multispray and lubricate the thread", 60, "1E", "w"),
    ("BEARING", 14, "Airr outlet of spindle: clean air outlets, replace filter pads", 60, "1M", "m"),
    ("BEARING", 15, "Locking head (Pos.980)and ring (Pos.815): check radial and lateral runout of locking head and ring", 60, "1M", "m"),
    ("BEARING", 16, "Position of pin in ring (Pos. 925): check fixing of pin", 60, "1M", "m"),
    ("BEARING", 17, "Grease nipple (Pos.530)in lower rim fixture (Pos.825): Grease with Shell Gadus", 30, "1M", "w"),
    ("BEARING", 18, "Rim and interlocking system: check snap-in finction", 60, "1M", "m"),
    ("BEARING", 19, "Screw connection: check scew tightening torque", 60, "1E", "y"),

    # Image 5
    ("SOAP STATION", 1, "Toothed belt : Clean and replace if necessary", 60, "1E", "6m"),
    ("SOAP STATION", 2, "Toothed belt disc :Clean and replace if necessary", 60, "1E", "6m"),
    ("SOAP STATION", 3, "damper:Clean and replace if necessary", 30, "1M", "3m"),
    ("SOAP STATION", 4, "roller:Clean and replace if necessary", 60, "1E", "6m"),
    ("SOAP STATION", 5, "transmission wheels:Clean and replace if necessary", 20, "1E", "6m"),
    ("SOAP STATION", 6, "transmission chains:Clean and replace if necessary", 30, "1M", "3m"),
    ("SCANNING DEVICE", 7, "Mirror: clean the mirror", 90, "1M", "m"),
    ("SCANNING DEVICE", 8, "Function: Clean the lens", 20, "1M", "m"),
    ("IN-CONVEYOR", 9, "Toothed belt : Clean and replace if necessary", 10, "1M", "3m"),
    ("IN-CONVEYOR", 10, "Toothed belt disc :Clean and replace if necessary", 20, "1M", "6m"),
    ("LIFTING UNIT", 11, "Function: check ease of movement, hose laying, damages", 60, "1E", "m"),
    ("LIFTING UNIT", 12, "Rollers: Clean, check for damage and replace if necessary", 30, "1M", "3m"),
    ("CENTERING DEVICE", 13, "Ball screw: Clean, check for damage and replace if necessary", 60, "1E", "y"),
    ("CENTERING DEVICE", 14, "Guide carriages and rails: Clean, check for damage and replace if necessary", 60, "1M", "6m"),
    ("CENTERING DEVICE", 15, "Hoses & cables in power track : Clean, check for damage and replace if necessary", 60, "1M", "y"),
    ("CENTERING DEVICE", 16, "Roller: Clean, check for damage and replace if necessary", 60, "1M", "m"),
    ("SOAPING DEVICE", 17, "Soap coverd surfaces: Remove soap residue,clean components & function check", 30, "1M", "w"),
    ("SOAPING DEVICE", 18, "Brushes: Check condition of bristles and replace brush if necessary", 60, "1M", "w"),
    ("SOAPING DEVICE", 19, "Guides,rail guide,carriage,bushing &guide bolt: Clean,check function of all guides rails & carriages", 60, "1E", "m"),
    ("SOAPING DEVICE", 20, "Roller: Check for wear", 60, "1E", "3m"),
]

elec_rows = []
mech_rows = []

for item in all_tasks:
    sub_mach, idx, desc, mins, crew, freq_str = item
    
    # Parse period and start week
    period, start_week = parse_freq(freq_str)
    
    row = {
        'Machine': "ZF Machine",
        'Sub_Machine': sub_mach,
        '.': idx,
        'Task_Description': desc,
        'Task_Code': "ZF", # SET TO ZF AS REQUESTED
        'Estimated_mins': mins,
        'Crew': crew,
        'Period_freq': period
    }
    
    # Generate week flags
    week_flags = get_weeks(period, start_week)
    for w_idx, flag in enumerate(week_flags, 1):
        row[f'W{w_idx}'] = flag

    if "1E" in crew:
        elec_rows.append(row)
    else:
        mech_rows.append(row)

# Create DataFrames
df_elec = pd.DataFrame(elec_rows, columns=columns)
df_mech = pd.DataFrame(mech_rows, columns=columns)

# Save to CSVs
df_elec.to_csv('table/ZF_Electrical_PM_Plan.csv', index=False, encoding='utf-8-sig')
df_mech.to_csv('table/ZF_Mechanical_PM_Plan.csv', index=False, encoding='utf-8-sig')

print("Files generated: 'table/ZF_Electrical_PM_Plan.csv' and 'table/ZF_Mechanical_PM_Plan.csv'")
# Out:
# Files generated: 'table/ZF_Electrical_PM_Plan.csv' and 'table/ZF_Mechanical_PM_Plan.csv'

# %%
import pandas as pd
import os
import glob

# Define the folder path
folder_path = 'table'

# Get a list of all CSV files in the folder
all_files = glob.glob(os.path.join(folder_path, "*.csv"))

# List to hold individual DataFrames
df_list = []

print(f"Found {len(all_files)} CSV files to merge...")

for filename in all_files:
    # Read each CSV
    df = pd.read_csv(filename)
    
    # Optional: Add a column to track which file the data came from
    # df['Source_File'] = os.path.basename(filename)
    
    df_list.append(df)

# Concatenate all DataFrames
if df_list:
    merged_df = pd.concat(df_list, ignore_index=True)

    # Save the merged file
    output_filename = "Inspection_Electrical_PM_Plan.csv"
    merged_df.to_csv(output_filename, index=False, encoding='utf-8-sig')

    print(f"Successfully merged {len(all_files)} files into '{output_filename}'.")
    print(f"Total rows: {len(merged_df)}")
else:
    print("No CSV files found in the 'table/' directory.")
# Out:
# Found 16 CSV files to merge...
# Successfully merged 16 files into 'Inspection_Electrical_PM_Plan.csv'.
# Total rows: 413
